# %% [markdown]
# # train,test데이터 가져오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/금융문자/데이터')

# %%
import pandas as pd
# train = pd.read_csv('30000.csv',names=['text','smishing'])
train = pd.read_csv('sam60K_lvDist_0_82222_1_whole.csv', names=['text','smishing'])
print(train.shape)
train.head()
# Out:
# (60038, 2)
#                                                                                                            text            smishing
# id     year_month text                                         smishing prep                                len              lvDist
# 303496 2018-09    ㅡ                                            0        NaN                                   0                 1.0
# 147557 2017-08    XXXㅐㅐ                                        0                                              1                 1.0
# 257777 2018-04    XXX0415 14:22XXXXXXXX카드스마트XXX710000잔액4869889 0         04151422 카드스마트 710000잔액4869889      31   0.967741935483871
# 84368  2017-05    XX-XXX-XXX0전화하셔서0번누르시면상담원연결됩니다.사용자계약번호확인해주세요 0         0전화하셔서0번누르시면상담원연결됩니다사용자계약번호확인해주세요   34  0.9473684210526315

# %%
test = pd.read_csv('public_test.csv',encoding='euc-kr')
print(test.shape)
test.head()
# Out:
# (1626, 3)
#        id year_month                                               text
# 0  340000    2019-01  XXX고객님! 안녕하세요? 새롭게 시작하는 한 주 행복 가득하시길 기원합니다. 지난...
# 1  340001    2019-01   긴급 안내  XXX은행 가락동 지점  - 헬리오XXX 기본XXX    대출이자를 ...
# 2  340002    2019-01  XXX 고객님 안녕하세요올해는 미세먼지가 유난인거 같습니다.엊그제 새해가 시작된거같...
# 3  340003    2019-01  XXX 고객님찾아온 행운을 잡으셨나요? 못잡으셨다면 이번에 다시 잡으시길 기원합니다...
# 4  340004    2019-01  XXX 고객님새해 복 많이 받으세요 XXX은행 코스트코 퇴직연금 담당자입니다.  고...

# %%
# import tensorflow as tf
# from keras.datasets import imdb
# from keras.preprocessing.sequence import pad_sequences
# vocab_size = 20000
# (X_train2,Y_train2),(X_test,Y_test) = imdb.load_data(num_words=vocab_size)

# %%
# max_len = 500
# X_train2 = pad_sequences(X_train2, maxlen=max_len)
# X_test2 = pad_sequences(X_test, maxlen=max_len)

# %% [markdown]
# #언더샘플링 (스미싱과 아닌것 6.6%씩)

# %%
# 스미싱 개수 파악
from collections import Counter

Counter(train['smishing'])
# Out:
# Counter({'lvDist': 1,
#          '1.0': 29,
#          '0.967741935483871': 36,
#          '0.9473684210526315': 36,
#          '0.9117647058823529': 193,
#          '0.9444444444444444': 69,
#          '0.8461538461538461': 227,
#          '0.985': 1,
#          '0.9690048939641109': 1,
#          '0.9865871833084948': 1,
#          '0.9735449735449735': 1,
#          '0.9858757062146892': 1,
#          '0.9299363057324841': 3,
#          '0.9394904458598726': 2,
#          '0.8846153846153846': 102,
#          '0.9459041731066461': 1,
#          '0.9455782312925171': 5,
#          '0.8648648648648649': 166,
#          '0.8378378378378378': 156,
#          '0.8285714285714286': 379,
#          '0.8857142857142857': 236,
#          '0.896551724137931': 123,
#          '0.9642857142857143': 12,
#          '0.8363636363636363': 58,
#          '0.9272727272727272': 15,
#          '0.8921568627450981': 21,
#          '0.9019607843137255': 30,
#          '0.9': 251,
#          '0.9622641509433962': 7,
#          '0.8947368421052632': 108,
#          '0.9210526315789473': 38,
#          '0.9487179487179487': 15,
#          '0.9253539253539254': 2,
#          '0.9536178107606679': 1,
#          '0.8529411764705882': 359,
#          '0.9447852760736196': 6,
#          '0.918918918918919': 64,
#          '0.910958904109589': 10,
#          '0.9041095890410958': 15,
#          '0.9285714285714286': 82,
#          '0.8813559322033898': 35,
#          '0.8633257403189066': 2,
#          '0.8485639686684073': 1,
#          '0.9295774647887324': 11,
#          '0.9889196675900277': 1,
#          '0.9916897506925207': 1,
#          '0.9387755102040817': 13,
#          '0.9269406392694064': 2,
#          '0.9315068493150684': 11,
#          '0.9420731707317073': 3,
#          '0.952': 5,
#          '0.9150326797385621': 8,
#          '0.9411764705882353': 97,
#          '0.9038461538461539': 33,
#          '0.8923076923076924': 32,
#          '0.8955223880597015': 29,
#          '0.8592592592592593': 10,
#          '0.9028571428571428': 6,
#          '0.9453302961275627': 1,
#          '0.9344262295081968': 18,
#          '0.9827586206896551': 2,
#          '0.877906976744186': 9,
#          '0.8953488372093024': 20,
#          '0.9747023809523809': 1,
#          '0.9267015706806283': 7,
#          '0.91005291005291': 4,
#          '0.8469387755102041': 32,
#          '0.8315789473684211': 27,
#          '0.8526315789473684': 39,
#          '0.8681318681318682': 29,
#          '0.8736842105263158': 24,
#          '0.875': 512,
#          '0.9120879120879121': 20,
#          '0.9559585492227979': 1,
#          '0.8717948717948718': 68,
#          '0.8235294117647058': 498,
#          '0.963855421686747': 4,
#          '0.85': 158,
#          '0.8448275862068966': 47,
#          '0.9519867549668874': 1,
#          '0.9182389937106918': 8,
#          '0.9119496855345912': 5,
#          '0.8823529411764706': 300,
#          '0.8387096774193549': 349,
#          '0.936': 7,
#          '0.912': 16,
#          '0.8571428571428571': 693,
#          '0.8918918918918919': 103,
#          '0.8611111111111112': 213,
#          '0.9783333333333334': 6,
#          '0.8928571428571429': 104,
#          '0.8854961832061069': 14,
#          '0.9714285714285714': 28,
#          '0.84375': 377,
#          '0.9287356321839081': 1,
#          '0.9494252873563218': 2,
#          '0.95': 23,
#          '0.9354838709677419': 99,
#          '0.9230769230769231': 90,
#          '0.9423076923076923': 20,
#          '0.8990825688073395': 12,
#          '0.8440366972477065': 16,
#          '0.9166666666666666': 162,
#          '0.84': 121,
#          '0.9244186046511628': 6,
#          '0.9183673469387755': 29,
#          '0.8245614035087719': 43,
#          '0.8319327731092437': 26,
#          '0.851063829787234': 62,
#          '0.8275862068965517': 241,
#          '0.9531914893617022': 2,
#          '0.9702127659574468': 1,
#          '0.9665653495440729': 1,
#          '0.9253731343283582': 18,
#          '0.8771929824561403': 34,
#          '0.8666666666666667': 298,
#          '0.8269230769230769': 48,
#          '0.8634361233480177': 6,
#          '0.8854625550660793': 6,
#          '0.8848484848484849': 7,
#          '0.8354430379746836': 36,
#          '0.9372693726937269': 2,
#          '0.9090909090909091': 268,
#          '0.9406528189910979': 1,
#          '0.8961424332344213': 2,
#          '0.8978494623655914': 5,
#          '0.8978328173374613': 3,
#          '0.9009287925696594': 2,
#          '0.914572864321608': 3,
#          '0.8741721854304636': 12,
#          '0.8344370860927153': 14,
#          '0.9036144578313253': 13,
#          '0.8975903614457831': 6,
#          '0.8659217877094972': 6,
#          '0.8938547486033519': 10,
#          '0.869757174392936': 2,
#          '0.9044289044289044': 1,
#          '0.8278688524590164': 15,
#          '0.8596491228070176': 54,
#          '0.8304093567251462': 14,
#          '0.8414634146341463': 30,
#          '0.8541666666666666': 45,
#          '0.8796992481203008': 12,
#          '0.8450704225352113': 44,
#          '0.868421052631579': 80,
#          '0.8835616438356164': 10,
#          '0.8674351585014409': 1,
#          '0.8472622478386167': 1,
#          '0.8581081081081081': 23,
#          '0.8513513513513513': 41,
#          '0.8240740740740741': 31,
#          '0.9017857142857143': 15,
#          '0.8933333333333333': 18,
#          '0.8604651162790697': 80,
#          '0.8764044943820225': 26,
#          '0.898876404494382': 25,
#          '0.9097744360902256': 9,
#          '0.8646616541353384': 21,
#          '0.9216417910447762': 3,
#          '0.9350180505415162': 2,
#          '0.9171270718232044': 10,
#          '0.8535911602209945': 3,
#          '0.9617021276595744': 2,
#          '0.8685446009389671': 11,
#          '0.8779342723004695': 4,
#          '0.855072463768116': 58,
#          '0.90625': 198,
#          '0.8554216867469879': 36,
#          '0.9195402298850575': 10,
#          '0.8390804597701149': 32,
#          '0.9259259259259259': 47,
#          '0.9798387096774194': 1,
#          '0.8669354838709677': 2,
#          '0.9470899470899471': 2,
#          '0.8256880733944955': 22,
#          '0.9174311926605505': 13,
#          '0.9143835616438356': 2,
#          '0.8969072164948454': 27,
#          '0.8995433789954338': 2,
#          '0.8333333333333334': 834,
#          '0.8478260869565217': 49,
#          '0.8731343283582089': 14,
#          '0.8418367346938775': 8,
#          '0.9126506024096386': 1,
#          '0.8855421686746988': 9,
#          '0.8671328671328671': 17,
#          '0.8653846153846154': 49,
#          '0.8782051282051282': 12,
#          '0.8583333333333333': 15,
#          '0.8544303797468354': 11,
#          '0.8291139240506329': 6,
#          '0.853448275862069': 18,
#          '0.888': 24,
#          '0.8352941176470589': 29,
#          '0.8888888888888888': 374,
#          '0.8626373626373627': 13,
#          '0.8351648351648352': 30,
#          '0.9152542372881356': 27,
#          '0.9279661016949152': 1,
#          '0.8693877551020408': 3,
#          '0.9358974358974359': 11,
#          '0.950354609929078': 6,
#          '0.8439716312056738': 22,
#          '0.8590604026845637': 11,
#          '0.8303571428571429': 23,
#          '0.9315476190476191': 2,
#          '0.9134615384615384': 11,
#          '0.8701923076923077': 6,
#          '0.845771144278607': 7,
#          '0.8359375': 20,
#          '0.9297520661157025': 3,
#          '0.9008264462809917': 11,
#          '0.8669833729216152': 1,
#          '0.892018779342723': 5,
#          '0.8591549295774648': 46,
#          '0.8488372093023255': 29,
#          '0.8662790697674418': 4,
#          '0.8883720930232558': 10,
#          '0.8790697674418605': 6,
#          '0.879746835443038': 11,
#          '0.8645418326693227': 4,
#          '0.9043824701195219': 2,
#          '0.8547008547008547': 18,
#          '0.8895027624309392': 8,
#          '0.856353591160221': 11,
#          '0.896414342629482': 4,
#          '0.8804780876494024': 3,
#          '0.896': 20,
#          '0.884': 4,
#          '0.8405797101449275': 32,
#          '0.8735177865612648': 5,
#          '0.8656126482213439': 4,
#          '0.8264462809917356': 17,
#          '0.835820895522388': 39,
#          '0.8415300546448088': 8,
#          '0.8583690987124464': 6,
#          '0.8446969696969697': 3,
#          '0.9124668435013262': 2,
#          '0.8425531914893617': 3,
#          '0.8680851063829788': 5,
#          '0.9125799573560768': 2,
#          '0.8827292110874201': 1,
#          '0.8919449901768173': 1,
#          '0.8322368421052632': 2,
#          '0.8765182186234818': 1,
#          '0.8619631901840491': 6,
#          '0.8757763975155279': 9,
#          '0.8695652173913043': 123,
#          '0.8414096916299559': 2,
#          '0.8273092369477911': 4,
#          '0.8949579831932774': 3,
#          '0.9138655462184874': 2,
#          '0.8962025316455696': 2,
#          '0.8421052631578947': 164,
#          '0.8512396694214877': 23,
#          '0.8677685950413223': 24,
#          '0.9054054054054054': 16,
#          '0.8292682926829268': 55,
#          '0.8586387434554974': 10,
#          '0.9244604316546763': 2,
#          '0.920863309352518': 8,
#          '0.947986577181208': 1,
#          '0.9580536912751678': 1,
#          '0.8714285714285714': 40,
#          '0.8289473684210527': 40,
#          '0.8552631578947368': 37,
#          '0.8282828282828283': 25,
#          '0.8444444444444444': 65,
#          '0.8455882352941176': 17,
#          '0.8770491803278688': 13,
#          '0.8543689320388349': 28,
#          '0.8398058252427184': 3,
#          '0.831858407079646': 23,
#          '0.8266666666666667': 37,
#          '0.8620689655172413': 184,
#          '0.8617886178861789': 18,
#          '0.8406593406593407': 4,
#          '0.890625': 22,
#          '0.9010416666666666': 5,
#          '0.8484848484848485': 384,
#          '0.9101123595505618': 29,
#          '0.8492063492063492': 17,
#          '0.8508771929824561': 20,
#          '0.9073359073359073': 1,
#          '0.8454545454545455': 28,
#          '0.8941176470588236': 22,
#          '0.8634538152610441': 3,
#          '0.8755020080321285': 3,
#          '0.8356164383561644': 34,
#          '0.9080459770114943': 14,
#          '0.8505747126436781': 43,
#          '0.8647058823529412': 9,
#          '0.9235294117647059': 10,
#          '0.8514851485148515': 28,
#          '0.8493150684931506': 35,
#          '0.8802083333333334': 5,
#          '0.9322916666666666': 3,
#          '0.8741258741258742': 17,
#          '0.9216867469879518': 5,
#          '0.9246987951807228': 2,
#          '0.8260869565217391': 109,
#          '0.8642857142857143': 16,
#          '0.825': 74,
#          '0.8899082568807339': 21,
#          '0.9209621993127147': 5,
#          '0.8694158075601375': 4,
#          '0.8778280542986425': 6,
#          '0.9314420803782506': 3,
#          '0.8711656441717791': 6,
#          '0.8650306748466258': 9,
#          '0.9093333333333333': 1,
#          '0.8986666666666666': 1,
#          '0.9358288770053476': 4,
#          '0.9069767441860465': 40,
#          '0.8222222222222222': 56,
#          '0.8587360594795539': 2,
#          '0.9014084507042254': 34,
#          '0.8680555555555556': 9,
#          '0.8645833333333334': 45,
#          '0.8740157480314961': 14,
#          '0.9133858267716536': 8,
#          '0.9296482412060302': 2,
#          '0.8944723618090452': 9,
#          '0.92': 47,
#          '0.9132075471698113': 3,
#          '0.9029850746268657': 8,
#          '0.8538461538461538': 20,
#          '0.9103448275862069': 8,
#          '0.9310344827586207': 62,
#          '0.8790322580645161': 24,
#          '0.852112676056338': 13,
#          '0.9198606271777003': 2,
#          '0.8804347826086957': 20,
#          '0.8433734939759037': 43,
#          '0.8686868686868687': 18,
#          '0.8875739644970414': 5,
#          '0.8579881656804734': 8,
#          '0.8840579710144928': 33,
#          '0.933649289099526': 5,
#          '0.9052132701421801': 5,
#          '0.8795180722891566': 30,
#          '0.8382352941176471': 52,
#          '0.9382716049382716': 6,
#          '0.9085714285714286': 5,
#          '0.859504132231405': 15,
#          '0.8376623376623377': 20,
#          '0.8831168831168831': 24,
#          '0.9576059850374065': 1,
#          '0.9102244389027432': 2,
#          '0.8725490196078431': 25,
#          '0.9537037037037037': 4,
#          '0.8736141906873615': 1,
#          '0.8638838475499092': 1,
#          '0.858560794044665': 1,
#          '0.8800904977375565': 1,
#          '0.9025522041763341': 1,
#          '0.8259860788863109': 1,
#          '0.8364661654135338': 1,
#          '0.8631756756756757': 2,
#          '0.954639175257732': 1,
#          '0.9045454545454545': 3,
#          '0.9130434782608695': 64,
#          '0.94824016563147': 1,
#          '0.9331797235023042': 1,
#          '0.9470046082949308': 1,
#          '0.8842105263157894': 24,
#          '0.8321678321678322': 17,
#          '0.8393782383419689': 9,
#          '0.8343949044585988': 9,
#          '0.8427672955974843': 12,
#          '0.8349514563106796': 34,
#          '0.8704318936877077': 2,
#          '0.8471760797342193': 1,
#          '0.8290155440414507': 10,
#          '0.8301886792452831': 63,
#          '0.8256410256410256': 7,
#          '0.8475336322869955': 6,
#          '0.8288770053475936': 7,
#          '0.8563829787234043': 6,
#          '0.9271948608137045': 1,
#          '0.9239130434782609': 11,
#          '0.8851063829787233': 6,
#          '0.8553191489361702': 8,
#          '0.9014778325123153': 2,
#          '0.8651685393258427': 32,
#          '0.8316831683168316': 30,
#          '0.8369565217391305': 27,
#          '0.8345864661654135': 15,
#          '0.8872180451127819': 26,
#          '0.8589743589743589': 32,
#          '0.9206349206349206': 19,
#          '0.8322981366459627': 18,
#          '0.906832298136646': 12,
#          '0.8617511520737328': 3,
#          '0.8585858585858586': 27,
#          '0.8373205741626795': 1,
#          '0.8803827751196173': 6,
#          '0.8709677419354839': 255,
#          '0.9271844660194175': 5,
#          '0.8936170212765957': 42,
#          '0.9042553191489362': 16,
#          '0.8768115942028986': 15,
#          '0.8789808917197452': 6,
#          '0.8657718120805369': 7,
#          '0.9087837837837838': 4,
#          '0.8783783783783784': 34,
#          '0.824': 24,
#          '0.8849557522123894': 25,
#          '0.8942307692307693': 22,
#          '0.8545454545454545': 44,
#          '0.8727272727272727': 44,
#          '0.868': 3,
#          '0.8609271523178808': 13,
#          '0.832': 17,
#          '0.8674698795180723': 41,
#          '0.8675213675213675': 2,
#          '0.8636363636363636': 107,
#          '0.8873239436619719': 32,
#          '0.8491379310344828': 4,
#          '0.8879310344827587': 19,
#          '0.8320610687022901': 24,
#          '0.8584905660377359': 31,
#          '0.8726415094339622': 7,
#          '0.8287671232876712': 13,
#          '0.8896797153024911': 2,
#          '0.8576512455516014': 2,
#          '0.8719512195121951': 13,
#          '0.865546218487395': 24,
#          '0.883495145631068': 23,
#          '0.8932038834951457': 28,
#          '0.8522727272727273': 54,
#          '0.8380281690140845': 14,
#          '0.8633879781420765': 9,
#          '0.8909090909090909': 47,
#          '0.8962264150943396': 24,
#          '0.8827160493827161': 10,
#          '0.898989898989899': 16,
#          '0.9049773755656109': 7,
#          '0.8418803418803419': 5,
#          '0.826530612244898': 27,
#          '0.9002770083102493': 2,
#          '0.9085872576177285': 1,
#          '0.8490566037735849': 45,
#          '0.8701298701298701': 30,
#          '0.9204152249134948': 2,
#          '0.9065743944636678': 4,
#          '0.8673469387755102': 23,
#          '0.8705357142857143': 5,
#          '0.9293286219081273': 3,
#          '0.901060070671378': 3,
#          '0.9106529209621993': 2,
#          '0.9296875': 7,
#          '0.9222222222222223': 12,
#          '0.8598130841121495': 26,
#          '0.907563025210084': 14,
#          '0.8853503184713376': 12,
#          '0.9127906976744186': 5,
#          '0.9022988505747126': 2,
#          '0.9217877094972067': 7,
#          '0.9333333333333333': 84,
#          '0.8765957446808511': 3,
#          '0.8582995951417004': 2,
#          '0.8767123287671232': 33,
#          '0.8949771689497716': 6,
#          '0.9142857142857143': 173,
#          '0.85995085995086': 1,
#          '0.8631578947368421': 39,
#          '0.8222811671087533': 1,
#          '0.8483965014577259': 1,
#          '0.8451443569553806': 2,
#          '0.84251968503937': 23,
#          '0.841897233201581': 2,
#          '0.8705882352941177': 29,
#          '0.8764705882352941': 9,
#          '0.8722222222222222': 8,
#          '0.8509316770186336': 15,
#          '0.8385093167701864': 9,
#          '0.8874172185430463': 10,
#          '0.8807947019867549': 9,
#          '0.8548387096774194': 35,
#          '0.8341232227488151': 6,
#          '0.8556149732620321': 5,
#          '0.87': 22,
#          '0.83': 28,
#          '0.9213483146067416': 15,
#          '0.9424460431654677': 3,
#          '0.8515625': 18,
#          '0.8739130434782608': 7,
#          '0.8913043478260869': 49,
#          '0.9570815450643777': 1,
#          '0.8755364806866953': 2,
#          '0.8532110091743119': 12,
#          '0.8924731182795699': 17,
#          '0.9175627240143369': 2,
#          '0.8926553672316384': 4,
#          '0.9306930693069307': 8,
#          '0.8989547038327527': 1,
#          '0.9337979094076655': 1,
#          '0.8230088495575221': 21,
#          '0.8516746411483254': 5,
#          '0.8787878787878788': 324,
#          '0.873015873015873': 50,
#          '0.8677248677248677': 8,
#          '0.8901515151515151': 1,
#          '0.9053030303030303': 1,
#          '0.856': 24,
#          '0.8560885608856088': 3,
#          '0.8819188191881919': 2,
#          '0.8415841584158416': 29,
#          '0.8314606741573034': 27,
#          '0.8713450292397661': 7,
#          '0.8539325842696629': 32,
#          '0.8489208633093526': 18,
#          '0.8754863813229572': 6,
#          '0.8404669260700389': 2,
#          '0.8272727272727273': 21,
#          '0.827027027027027': 5,
#          '0.8322147651006712': 10,
#          '0.8855721393034826': 7,
#          '0.8503937007874016': 22,
#          '0.8379888268156425': 4,
#          '0.8603351955307262': 12,
#          '0.8442906574394463': 2,
#          '0.8858131487889274': 3,
#          '0.8884892086330936': 3,
#          '0.9157509157509157': 2,
#          '0.8677354709418837': 1,
#          '0.8797595190380761': 1,
#          '0.8873873873873874': 4,
#          '0.8894009216589862': 8,
#          '0.8294573643410853': 23,
#          '0.8697318007662835': 2,
#          '0.823943661971831': 8,
#          '0.8754716981132076': 3,
#          '0.8226415094339623': 2,
#          '0.9031413612565445': 1,
#          '0.8743455497382199': 8,
#          '0.8233333333333334': 1,
#          '0.8360655737704918': 40,
#          '0.8446601941747572': 27,
#          '0.8472222222222222': 33,
#          '0.8564356435643564': 4,
#          '0.8456375838926175': 10,
#          '0.8507462686567164': 55,
#          '0.8253275109170306': 1,
#          '0.8297872340425532': 57,
#          '0.8634146341463415': 13,
#          '0.8390243902439024': 6,
#          '0.8223350253807107': 3,
#          '0.8426395939086294': 11,
#          '0.8372093023255814': 75,
#          '0.869281045751634': 15,
#          '0.8431372549019608': 67,
#          '0.884318766066838': 2,
#          '0.8997429305912596': 1,
#          '0.8394495412844036': 5,
#          '0.8302752293577982': 1,
#          '0.8263888888888888': 11,
#          '0.867579908675799': 3,
#          '0.8963963963963963': 3,
#          '0.8761061946902655': 24,
#          '0.9136690647482014': 15,
#          '0.9100719424460432': 1,
#          '0.831081081081081': 19,
#          '0.8300653594771242': 7,
#          '0.8290598290598291': 17,
#          '0.903485254691689': 2,
#          '0.8954423592493298': 2,
#          '0.8770764119601329': 3,
#          '0.8364389233954451': 1,
#          '0.8676470588235294': 30,
#          '0.8288288288288288': 23,
#          '0.867109634551495': 2,
#          '0.8773584905660378': 22,
#          '0.8608058608058609': 4,
#          '0.8402777777777778': 12,
#          '0.8441558441558441': 34,
#          '0.8380952380952381': 23,
#          '0.8296943231441049': 5,
#          '0.851528384279476': 4,
#          '0.8345323741007195': 12,
#          '0.913946587537092': 1,
#          '0.9080118694362018': 2,
#          '0.8661971830985915': 15,
#          '0.84765625': 3,
#          '0.8305084745762712': 31,
#          '0.8848920863309353': 18,
#          '0.8428571428571429': 46,
#          '0.8497854077253219': 7,
#          '0.8348623853211009': 28,
#          '0.9249329758713136': 1,
#          '0.9329758713136729': 1,
#          '0.83125': 10,
#          '0.8353658536585366': 13,
#          '0.8445378151260504': 3,
#          '0.8350515463917526': 23,
#          '0.8968609865470852': 5,
#          '0.900990099009901': 17,
#          '0.9086294416243654': 6,
#          '0.8518518518518519': 165,
#          '0.8817204301075269': 30,
#          '0.953405017921147': 2,
#          '0.9154411764705882': 2,
#          '0.9227941176470589': 4,
#          '0.9416666666666667': 5,
#          '0.9293478260869565': 4,
#          '0.8976744186046511': 3,
#          '0.9027355623100304': 3,
#          '0.9148936170212766': 28,
#          '0.8313725490196079': 3,
#          '0.8711111111111111': 3,
#          '0.8755555555555555': 8,
#          '0.8629032258064516': 17,
#          '0.8495575221238938': 19,
#          '0.8938053097345132': 20,
#          '0.8844221105527639': 3,
#          '0.9081632653061225': 21,
#          '0.9078014184397163': 13,
#          '0.9163987138263665': 3,
#          '0.8681672025723473': 2,
#          '0.8766666666666667': 3,
#          '0.8707482993197279': 16,
#          '0.8403755868544601': 5,
#          '0.8734177215189873': 30,
#          '0.8295454545454546': 37,
#          '0.8253968253968254': 45,
#          '0.8435374149659864': 12,
#          '0.8626609442060086': 9,
#          '0.8932384341637011': 4,
#          '0.8703703703703703': 50,
#          '0.8901098901098901': 20,
#          '0.8715953307392996': 4,
#          '0.8521400778210116': 6,
#          '0.8411214953271028': 23,
#          '0.9228650137741047': 1,
#          '0.8539944903581267': 1,
#          '0.8273809523809523': 9,
#          '0.8640776699029126': 33,
#          '0.9111675126903553': 1,
#          '0.8604060913705583': 1,
#          '0.8370786516853933': 10,
#          '0.8376068376068376': 28,
#          '0.8639705882352942': 3,
#          '0.9080882352941176': 3,
#          '0.88268156424581': 8,
#          '0.8743718592964824': 7,
#          '0.8252427184466019': 31,
#          '0.8669064748201439': 6,
#          '0.8558558558558559': 22,
#          '0.8593272171253823': 2,
#          '0.8357142857142857': 17,
#          '0.9389002036659878': 1,
#          '0.8716904276985743': 1,
#          '0.859073359073359': 2,
#          '0.9458483754512635': 4,
#          '0.8679245283018868': 56,
#          '0.837037037037037': 18,
#          '0.864516129032258': 9,
#          '0.8963414634146342': 14,
#          '0.8395061728395061': 33,
#          '0.8277511961722488': 5,
#          '0.8708133971291866': 5,
#          '0.822429906542056': 18,
#          '0.8785046728971962': 20,
#          '0.8243243243243243': 51,
#          '0.8700564971751412': 10,
#          '0.847457627118644': 49,
#          '0.8732394366197183': 41,
#          '0.8690476190476191': 31,
#          '0.8658008658008658': 2,
#          '0.8502202643171806': 5,
#          '0.8819444444444444': 8,
#          '0.8267326732673267': 8,
#          '0.8452380952380952': 38,
#          '0.8971428571428571': 8,
#          '0.8809523809523809': 40,
#          '0.9150943396226415': 13,
#          '0.916030534351145': 13,
#          '0.8778625954198473': 13,
#          '0.8280254777070064': 14,
#          '0.8646864686468647': 2,
#          '0.8481848184818482': 2,
#          '0.8672839506172839': 4,
#          '0.8466666666666667': 10,
#          '0.8782608695652174': 13,
#          '0.9191176470588235': 9,
#          '0.8723404255319149': 51,
#          '0.9336734693877551': 2,
#          '0.9137055837563451': 6,
#          '0.8344827586206897': 10,
#          '0.8561151079136691': 14,
#          '0.9471544715447154': 3,
#          '0.9047619047619048': 69,
#          '0.8356807511737089': 4,
#          '0.8621794871794872': 4,
#          '0.8311688311688312': 34,
#          '0.829971181556196': 1,
#          '0.9116465863453815': 5,
#          '0.8533333333333334': 38,
#          '0.9192546583850931': 5,
#          '0.848': 21,
#          '0.8362573099415205': 11,
#          '0.8826530612244898': 8,
#          '0.8619402985074627': 4,
#          '0.8768656716417911': 2,
#          '0.8412698412698413': 51,
#          '0.9009009009009009': 12,
#          '0.8627450980392157': 47,
#          '0.8464052287581699': 2,
#          '0.8559322033898306': 16,
#          '0.8483606557377049': 3,
#          '0.8442622950819673': 22,
#          '0.8987341772151899': 21,
#          '0.8259493670886076': 3,
#          '0.8859649122807017': 22,
#          '0.881578947368421': 29,
#          '0.865': 8,
#          '0.8797653958944281': 1,
#          '0.906158357771261': 2,
#          '0.8639240506329114': 2,
#          '0.8955696202531646': 1,
#          '0.8791946308724832': 12,
#          '0.9178571428571428': 4,
#          '0.849624060150376': 14,
#          '0.8865248226950354': 15,
#          '0.859375': 43,
#          '0.8711340206185567': 9,
#          '0.8556701030927835': 30,
#          '0.8412017167381974': 5,
#          '0.8364485981308412': 5,
#          '0.8282208588957055': 17,
#          '0.8425925925925926': 24,
#          '0.8318965517241379': 3,
#          '0.8557692307692307': 24,
#          '0.8494623655913979': 38,
#          '0.8755760368663594': 3,
#          '0.8663594470046083': 4,
#          '0.8475609756097561': 14,
#          '0.8307692307692308': 51,
#          '0.8827586206896552': 5,
#          '0.8862068965517241': 2,
#          '0.915929203539823': 2,
#          '0.8841463414634146': 6,
#          '0.8829787234042553': 33,
#          '0.9064748201438849': 12,
#          '0.937888198757764': 4,
#          '0.8796296296296297': 17,
#          '0.9064039408866995': 6,
#          '0.8341013824884793': 4,
#          '0.8248847926267281': 5,
#          '0.8536585365853658': 73,
#          '0.8745644599303136': 3,
#          '0.845679012345679': 15,
#          '0.8473684210526315': 7,
#          '0.8781725888324873': 7,
#          '0.8934010152284264': 7,
#          '0.8641975308641975': 37,
#          '0.8277777777777777': 11,
#          '0.8614457831325302': 7,
#          '0.8523809523809524': 6,
#          '0.8807339449541285': 13,
#          '0.839572192513369': 7,
#          '0.8291457286432161': 10,
#          '0.8693467336683417': 6,
#          '0.8409090909090909': 67,
#          '0.845': 8,
#          '0.9016393442622951': 19,
#          '0.8436213991769548': 4,
#          '0.8248587570621468': 5,
#          '0.8918032786885246': 3,
#          '0.8911174785100286': 1,
#          '0.89198606271777': 5,
#          '0.8597560975609756': 11,
#          '0.84472049689441': 11,
#          '0.8743961352657005': 5,
#          '0.8384279475982532': 4,
#          '0.8623853211009175': 23,
#          '0.8366336633663366': 7,
#          '0.8804878048780488': 1,
#          '0.8951219512195122': 1,
#          '0.8554913294797688': 11,
#          '0.8228571428571428': 7,
#          '0.8293838862559242': 2,
#          '0.8271028037383178': 3,
#          '0.8791208791208791': 30,
#          '0.8416666666666667': 25,
#          '0.8368794326241135': 10,
#          '0.8908296943231441': 4,
#          '0.8774509803921569': 8,
#          '0.8671875': 20,
#          '0.8426966292134831': 26,
#          '0.8258426966292135': 5,
#          '0.8392857142857143': 44,
#          '0.8588235294117647': 32,
#          '0.8222996515679443': 3,
#          '0.867595818815331': 4,
#          '0.89': 23,
#          '0.890295358649789': 8,
#          '0.8958333333333334': 40,
#          '0.9441624365482234': 3,
#          '0.9087301587301587': 3,
#          '0.8383838383838383': 33,
#          '0.8811188811188811': 15,
#          '0.8818565400843882': 3,
#          '0.8456140350877193': 2,
#          '0.8952380952380953': 22,
#          '0.8367346938775511': 71,
#          '0.8634920634920635': 2,
#          '0.8984126984126984': 2,
#          '0.8464730290456431': 2,
#          '0.8582677165354331': 14,
#          '0.9140625': 11,
#          '0.8877005347593583': 8,
#          '0.88': 106,
#          '0.8609865470852018': 2,
#          '0.8340807174887892': 5,
#          '0.8820754716981132': 4,
#          '0.8721461187214612': 8,
#          '0.8858447488584474': 5,
#          '0.9032258064516129': 200,
#          '0.8449612403100775': 23,
#          '0.8564102564102564': 4,
#          '0.8642533936651584': 5,
#          '0.8373983739837398': 20,
#          '0.9020979020979021': 10,
#          '0.8728323699421965': 15,
#          '0.8683127572016461': 8,
#          '0.9511111111111111': 3,
#          '0.9270833333333334': 14,
#          '0.8397790055248618': 8,
#          '0.8729281767955801': 7,
#          '0.8465608465608465': 8,
#          '0.844311377245509': 13,
#          '0.8251748251748252': 13,
#          '0.8920454545454546': 8,
#          '0.8669950738916257': 8,
#          '0.9387308533916849': 1,
#          '0.8687089715536105': 2,
#          '0.897119341563786': 1,
#          '0.8743169398907104': 10,
#          '0.8895705521472392': 11,
#          '0.8899521531100478': 5,
#          '0.8278145695364238': 9,
#          '0.8832116788321168': 14,
#          '0.9051094890510949': 10,
#          '0.8745387453874539': 1,
#          '0.8468468468468469': 23,
#          '0.8561643835616438': 14,
#          '0.8704663212435233': 3,
#          '0.8359788359788359': 5,
#          '0.8346153846153846': 4,
#          '0.9304347826086956': 9,
#          '0.8470588235294118': 27,
#          '0.8862745098039215': 3,
#          '0.8988095238095238': 13,
#          '0.8682170542635659': 16,
#          '0.8868778280542986': 1,
#          '0.8263157894736842': 5,
#          '0.8368421052631579': 7,
#          '0.8870967741935484': 34,
#          '0.8602150537634409': 23,
#          '0.8440860215053764': 4,
#          '0.8607594936708861': 27,
#          '0.887459807073955': 5,
#          '0.8401639344262295': 4,
#          '0.8619246861924686': 10,
#          '0.8533834586466166': 3,
#          '0.8764478764478765': 4,
#          '0.8622047244094488': 6,
#          '0.891156462585034': 16,
#          '0.8682634730538922': 20,
#          '0.8502994011976048': 11,
#          '0.8580246913580247': 17,
#          '0.8737201365187713': 5,
#          '0.864406779661017': 41,
#          '0.9186440677966101': 2,
#          '0.8845315904139434': 1,
#          '0.896328293736501': 1,
#          '0.8735632183908046': 26,
#          '0.8785714285714286': 9,
#          '0.89375': 15,
#          '0.824390243902439': 3,
#          '0.8396946564885496': 23,
#          '0.8358778625954199': 2,
#          '0.8535353535353535': 8,
#          '0.8689320388349514': 6,
#          '0.8940397350993378': 12,
#          '0.8531468531468531': 15,
#          '0.8865979381443299': 28,
#          '0.8247422680412371': 24,
#          '0.8775510204081632': 46,
#          '0.8737864077669902': 26,
#          '0.8375': 32,
#          '0.8418079096045198': 11,
#          '0.9005524861878453': 3,
#          '0.9237668161434978': 2,
#          '0.8584474885844748': 7,
#          '0.8842975206611571': 15,
#          '0.9024390243902439': 35,
#          '0.9508196721311475': 9,
#          '0.9017543859649123': 2,
#          '0.9157894736842105': 11,
#          '0.8253012048192772': 6,
#          '0.8482142857142857': 19,
#          '0.8429752066115702': 16,
#          '0.8690095846645367': 3,
#          '0.8672566371681416': 31,
#          '0.881159420289855': 2,
#          '0.8668639053254438': 3,
#          '0.8678678678678678': 1,
#          '0.8513931888544891': 1,
#          '0.8587570621468926': 3,
#          '0.844': 2,
#          '0.8594594594594595': 13,
#          '0.8625954198473282': 17,
#          '0.8875': 26,
#          '0.9429530201342282': 2,
#          '0.912751677852349': 18,
#          '0.8861386138613861': 8,
#          '0.863080684596577': 2,
#          '0.8608695652173913': 20,
#          '0.8816793893129771': 5,
#          '0.8838951310861424': 3,
#          '0.863013698630137': 29,
#          '0.8625592417061612': 4,
#          '0.8388625592417062': 6,
#          '0.8551724137931035': 22,
#          '0.8543046357615894': 17,
#          '0.8915094339622641': 5,
#          '0.8325358851674641': 5,
#          '0.8771186440677966': 4,
#          '0.8580645161290322': 15,
#          '0.86': 54,
#          '0.8671586715867159': 3,
#          '0.872093023255814': 31,
#          '0.8852459016393442': 32,
#          '0.8688524590163934': 52,
#          '0.8453237410071942': 2,
#          '0.8975155279503105': 3,
#          '0.8523076923076923': 3,
#          '0.8578199052132701': 10,
#          '0.9108910891089109': 12,
#          '0.917981072555205': 1,
#          '0.8370044052863436': 5,
#          '0.892128279883382': 2,
#          '0.893719806763285': 6,
#          '0.879245283018868': 3,
#          '0.8452830188679246': 1,
#          '0.8397435897435898': 12,
#          '0.8223684210526315': 12,
#          '0.8352272727272727': 12,
#          '0.8465909090909091': 8,
#          '0.8942598187311178': 1,
#          '0.864': 18,
#          '0.828125': 40,
#          '0.8423423423423423': 2,
#          '0.9146757679180887': 1,
#          '0.9014492753623189': 2,
#          '0.9043478260869565': 17,
#          '0.9100817438692098': 1,
#          '0.8828125': 13,
#          '0.8639455782312925': 9,
#          '0.8834355828220859': 14,
#          '0.9111969111969112': 2,
#          '0.9076923076923077': 32,
#          '0.9153846153846154': 11,
#          '0.8434343434343434': 9,
#          '0.8475836431226765': 3,
#          '0.8686131386861314': 15,
#          '0.8827361563517915': 2,
#          '0.8957654723127035': 2,
#          '0.8486842105263158': 18,
#          '0.8661087866108786': 3,
#          '0.8242424242424242': 8,
#          '0.9317269076305221': 4,
#          '0.9257028112449799': 1,
#          '0.8358974358974359': 4,
#          '0.8776978417266187': 12,
#          '0.8774193548387097': 18,
#          '0.8838709677419355': 10,
#          '0.8308823529411765': 18,
#          '0.8993055555555556': 2,
#          '0.9195979899497487': 1,
#          '0.8798449612403101': 1,
#          '0.8986175115207373': 3,
#          '0.8773946360153256': 3,
#          '0.8352490421455939': 3,
#          '0.8712121212121212': 12,
#          '0.8759124087591241': 19,
#          '0.8814814814814815': 21,
#          '0.8957528957528957': 3,
#          '0.8687258687258688': 4,
#          '0.8951612903225806': 11,
#          '0.9379562043795621': 2,
#          '0.8758169934640523': 16,
#          '0.903420523138833': 1,
#          '0.93158953722334': 1,
#          '0.8794642857142857': 3,
#          '0.8526785714285714': 3,
#          '0.8882978723404256': 6,
#          ...})

# %%
1511/0.06
# Out:
# 25183.333333333336

# %%
# 스미싱인 데이터의 6.6% 값 
18703*0.066
# Out:
# 1234.3980000000001

# %%
# 스미싱이 아닌 데이터의 6.6%의 값
277242*0.066
# Out:
# 18297.972

# %%
# # 랜덤으로 인덱스값 꺼내오기
# import random
# random.seed(2019)
# train_nsm_list=list(train[train['smishing']!=1].index)
# train_nsmishing = random.sample(train_nsm_list,18298)

# random.seed(2019)
# train_sm_list = list(train[train['smishing']==1].index)
# train_smishing = random.sample(train_sm_list,1235)

# %%
# 30000개로 추린 csv에 한한 코드
import random
random.seed(2019)
train_nsm_list=list(train[train['smishing']!=1].index)
train_nsmishing = random.sample(train_nsm_list,25000)

random.seed(2019)
train_sm_list = list(train[train['smishing']==1].index)
train_smishing = random.sample(train_sm_list,1500)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-56180f65994f> in <module>()
#       6 random.seed(2019)
#       7 train_sm_list = list(train[train['smishing']==1].index)
# ----> 8 train_smishing = random.sample(train_sm_list,1500)
#
# /usr/lib/python3.6/random.py in sample(self, population, k)
#     318         n = len(population)
#     319         if not 0 <= k <= n:
# --> 320             raise ValueError("Sample larger than population or is negative")
#     321         result = [None] * k
#     322         setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative

# %%
len(train_smishing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3e6ad6de7627> in <module>()
# ----> 1 len(train_smishing)
#
# NameError: name 'train_smishing' is not defined

# %%
# drop =True는 기존의 인덱스 컬럼을 드랍하는 것
train_xx = train.iloc[train_smishing+train_nsmishing,:].reset_index(drop=True)

# %%
train_yyy=train_xx['smishing']

# %%
# train_yy=pd.DataFrame(train['smishing'],columns=['smishing']) 
# train_yyy=train_yy.iloc[train_smishing+train_nsmishing,:].reset_index(drop=True)

# %%
test['smishing']=2 #train data와 동일한 형태 생성을 위해 임의의 숫자를 추가 #이후 스미싱 여부 확률 값으로 덮어 씌워짐
test_xx=pd.DataFrame(test['text'])
test_yyy=pd.DataFrame(test['smishing'])

# %%
# train_yy = pd.DataFrame()
# train_yy['smishing'] = train_xx['smishing']

# %%
train_xx
# Out:
#                                                     text  smishing
# 0      (광고)X (광고)(XXX)  전문상담원(XX-XXX-XXX 고객님께서는 국민행복기...         1
# 1         (광고)XXX1월이벤트빠르게천만원월39000원통화1번(무료거부XXX-XXX-XXX)         1
# 2      htmlbodyBR(광고)신용협동조합brbr함께 XXX고 어려울 때 힘이 되는 당신...         1
# 3      (광고)XX lt정확하고 올바른 신용대출gt  당사상품의 자격기준과 심사기준이 완화...         1
# 4      (광고)XXXbrbr (광고)XXX    믿음과 가치로 보답하는 XXX      가...         1
# ...                                                  ...       ...
# 26495  XXX 고객님신년도 달력 배부중이오니시간되실때 내점 부탁드려요XXX드리며쌀쌀한 날씨...         0
# 26496                   고객님의전담직원이되었습니다.든든한동반자가되겠습니다XXX올림         0
# 26497                          대출만기연장상담바랍니다XXX은행방이동XXX올림         0
# 26498                      기회를찾아야 기회를만든답니다 (ㅡ)XXX은행XXX올림         0
# 26499        1212(수)반포지점에서 가입한 예금만기입니다.시간내서 내점바랍니다.XXX탄현         0
#
# [26500 rows x 2 columns]

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# fatal: destination path 'Mecab-ko-for-Google-Colab' already exists and is not an empty directory.

# %%
ls
# Out:
# 30000.csv       ko.bin                      submission_제출양식.csv
# ansi_train.csv  Mecab-ko-for-Google-Colab/  검증.xlsx
# 데이터_EDA/     public_test.csv

# %%
cd Mecab-ko-for-Google-Colab/
# Out:
# /content/drive/My Drive/금융문자/데이터/Mecab-ko-for-Google-Colab

# %%
ls
# Out:
# images/  install_mecab-ko_on_colab190912.sh  README.md

# %%
# pip install konlpy하면 bash 실행해도 mecab설치 안됨 바로 bash실행
! bash install_mecab-ko_on_colab190912.sh
# Out:
# Installing konlpy.....
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 161kB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/d7/62/0f312d578e0165e9b5e8fcae0291f7ee83783b3805f59071006b21229d55/JPype1-0.7.1.tar.gz (481kB)
#      |████████████████████████████████| 491kB 65.1MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.17.4)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 13.7MB/s
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Building wheels for collected packages: JPype1
#   Building wheel for JPype1 (setup.py) ... done
#   Created wheel for JPype1: filename=JPype1-0.7.1-cp36-cp36m-linux_x86_64.whl size=2454536 sha256=a94835f071e752c672e6cadcc6919c8f95b984942ed973a189afeba9860bf58a
#   Stored in directory: /root/.cache/pip/wheels/b0/49/6a/4393ef8542c00becf80691bd242693db9e263d6e499323a984
# Successfully built JPype1
# Installing collected packages: tweepy, JPype1, colorama, beautifulsoup4, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-0.7.1 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.8.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2020-01-01 13:17:03--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.1, 18.205.93.0, 18.205.93.2, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=bnsApAH2LpS5ocx9%2BZOu8wgB6UM%3D&Expires=1577886423&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22 [following]
# --2020-01-01 13:17:03--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=bnsApAH2LpS5ocx9%2BZOu8wgB6UM%3D&Expires=1577886423&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.238.163
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.238.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  --.-KB/s    in 0.04s
#
# 2020-01-01 13:17:04 (38.6 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2020-01-01 13:18:26--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 18.205.93.0, 18.205.93.1, 18.205.93.2, ...
# Connecting to bitbucket.org (bitbucket.org)|18.205.93.0|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=HJu3f3JlCFWSk8wqQhWz5GG%2Bhm8%3D&Expires=1577886506&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22 [following]
# --2020-01-01 13:18:26--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=HJu3f3JlCFWSk8wqQhWz5GG%2Bhm8%3D&Expires=1577886506&AWSAccessKeyId=AKIAIQWXW6WLXMB5QZAQ&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.113.35
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.113.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M   114MB/s    in 0.4s
#
# 2020-01-01 13:18:26 (114 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()

# %%
# from konlpy.tag import Mecab
# tokenizer = Mecab()

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 179kB/s
# Collecting tweepy>=3.7.0
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/d7/62/0f312d578e0165e9b5e8fcae0291f7ee83783b3805f59071006b21229d55/JPype1-0.7.1.tar.gz (481kB)
#      |████████████████████████████████| 491kB 57.2MB/s
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 14.7MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.17.4)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.21.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Building wheels for collected packages: JPype1
#   Building wheel for JPype1 (setup.py) ... done
#   Created wheel for JPype1: filename=JPype1-0.7.1-cp36-cp36m-linux_x86_64.whl size=2438560 sha256=1aec8b07dcbf30099e9b127fc22e5678bd064cff25c353c7c5485c4a2796b3bf
#   Stored in directory: /root/.cache/pip/wheels/b0/49/6a/4393ef8542c00becf80691bd242693db9e263d6e499323a984
# Successfully built JPype1
# Installing collected packages: tweepy, JPype1, beautifulsoup4, colorama, konlpy
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-0.7.1 beautifulsoup4-4.6.0 colorama-0.4.3 konlpy-0.5.2 tweepy-3.8.0

# %%
import time
from konlpy.tag import Okt
tokenizer = Okt()

# %%
# import re
# pat =re.compile('[^가-힣0-9a-z ]')
# a= pat.sub('',train_xx['text'][0].lower())
# tokenizer.pos(a)

# %%
# 특수문자 제거 및 영어 소문자로 전환. 
import re
start = time.time()
pat = re.compile('[^가-힣0-9a-z!?% ]')
# a= train_xx['text'].apply(lambda x : pat.sub('',x.lower()))
a= train['text'].apply(lambda x : pat.sub('',x.lower()))
train_doc = [(tokenizer.pos(x),y) for x,y in zip(a,train)]
time.time() - start
# Out:
# 0.6324641704559326

# %%
# a= test['text'].apply(lambda x : pat.sub('',x.lower()))
# test_doc = [(tokenizer.pos(x),y) for x,y in zip(a,test_yyy['smishing'])]
test['smishing']

# %%
stopwords = ['xxx', '.', '을', '를', '이', '가', '-', '(', ')', ':', ')-', '.-', 'ㅡ', 'xxxxxx', '..', '.(', '은', '는'] #필요없는 단어 리스트

def get_couple(words):
    global stopwords
    words = [i[0] for i in words if i[0] not in stopwords]
    # words = [i[0] for i in words if len(i[0]) >1]
    return words

# %%
X_train, Y_train = [],[]

for lwords in train_doc:
    Y_train.append(lwords[1])

    temp = []

    for x in get_couple(lwords[0]):
        # if len(x) >1:
        temp.append(x)

    X_train.append(' '.join(temp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d492b87f1b1e> in <module>()
#       1 X_train, Y_train = [],[]
#       2
# ----> 3 for lwords in train_doc:
#       4     Y_train.append(lwords[1])
#       5
#
# NameError: name 'train_doc' is not defined

# %%
# 라벨을 numpy array형식으로 전환
import numpy as np

Y_train = np.array(Y_train)

# %%
train_xx['text'][0]
# Out:
# '(광고)X (광고)(XXX)  전문상담원(XX-XXX-XXX 고객님께서는 국민행복기금 신용보증증권 발행 XXX입니다.  한도금리 확인후 진행 도와드리겠습니다.  (한도는 고객 신용등급 및 직군소득확인에 따라 차등적용)  (고객 적용금리는 고객 신용등급은행기여도 등에 따라 차등 적용되며고객별 거래조건 및 상환능력 등에 의한 가산금리가 추가되어 적용)  우대금리: 최고 연 0.9% 중복우대  (신용카드 사용실적 우대: 최고 연0.3%할인)  (인터넷 또는 모바일뱅킹 신청이용고객: 연0.2%할인)  (급여이체고객: 연 0.2%할인)  (거래실적우대: 최고 연 0.2% 할인)  가산금리  (1000만원이하 소액: 연 1.0%가산)  보증보험료(1년기준:0.5%)  (일천만원 이상 신청건은 면제)  상환방식: 자율상환방식종합통장(마이너스)방식  기간: 1년10년(만기시연장)  상품혜택  (중도상환수수료취급수수료연장수수료계좌XXX수료 등.일체부과비용 없음)  대환목적 가능  신청방법 수신번호로 통화 또는 문자상XXX 상담가능시간 기재해주시면 전문상담원이 연락드리겠습니다.   XXX은행 여신영업부  전문상담원(XX-XXX-XXX 무료수신거부 XXX-XXX-XXX'

# %%
X_train[:5]
# Out:
# ['광고 x 광고 전 문 상담 원 xxxxxxxx 고객 님 께서는 국민 행복 기금 신용 보증 증권 발행 입니다 한도 금리 확인 후 진행 도 와 드리겠습니다 한도 고객 신용등급 및 직 군 소득 확인 에 따라 차등 적용 고객 적용 금리 고객 신용등급 은행 기여 도 등 에 따라 차등 적용 되며 고객 별 거래 조건 및 상환 능력 등 에 의한 가산금 리가 추가 되어 적용 우대금리 최고 연 09% 중복 우대 신용카드 사용 실적 우대 최고 연 03% 할인 인터넷 또는 모바일 뱅킹 신청 이용 고객 연 02% 할인 급여 이체 고객 연 02% 할인 거래 실적 우대 최고 연 02% 할인 가산 금리 1000만원 이하 소액 연 10% 가산 보증 보험료 1년 기준 05% 일천만원 이상 신청 건 면제 상환 방식 자율 상환 방식 종합 통장 마이너스 방식 기간 1년 10년 만기시연장 상품 혜택 중도 상환 수수료 취급 수수료 연장 수수료 계좌 수료 등 일체 부과 비용 없음 대 환 목적 가능 신청 방법 수 신 번호 로 통화 또는 문자 상 상담 가능 시간 기재 해주시면 전 문 상담 원 연락 드리겠습니다 은행 여신 영업 부 전 문 상담 원 xxxxxxxx 무료 수신 거부 xxxxxxxxx',
#  '광고 1월 이벤트빠르게천만원월 39000원 통화 1 번 무료 거부 xxxxxxxxx',
#  'htmlbodybr 광고 신용협동조합 brbr 함께 고 어려울 때 힘 되는 당신 의 든든한 동반 자 신협 입니다 brbr 안녕하세요 !! br 많은 업무 와 일상 에 바쁘시겠지만 잠시 시간 내어 읽어 주신다면 도움 되실 거 라 생각 되어 안 내 드립니다 brbr 신협 brbr 대상 연 소득 2천 이상 br 금리 최저 424% 989% br 기간 최대 10년 거치 만 기 상품 으로 이자 만 납 입하시거나 5년 분할상환 중 자유 선택 가능 brbr 1 담보 대출 대출 한도 에 영향 주지 않으므로 담보 대출 과 다 하여도 대출 가능 brbr 2 카드 론 2 금융 대출 있으셔도 대 환 대출 로 진행 가능 brbr 3 대출 건 수 현금 서비스 금액 많아도 예외 건 으로 진행 가능 brbr 4 신용등급 17등 급 진행 가능 brbr 많은 직장인 분들 바쁘셔서 혹은 시중 은행 가계 대출 신용 대출 제한 되면서 현금 서비스 및 고 금리 의 2 금융 권 상품 카드 론 많이 들 사용 하고 계십니다 brxxx 고객 님 들을 낮은 금리 의 전환 대출 및 부채 통합 도 와 드리고 있습니다 br 분산 된 부채 통합 시 신용등급 상승 및 매월 내시 불입 금액 에 대한 부담 감소 자비 용의 절감 brbr 이자 만 납 입시 br 5000만원 신청 시 매월 250417원 으로 이용 가능 합니다 brbr 5년 분할 납 입시 br 5000만원 신청 시 매월 966873원 원금이자으로 이용 가능 합니다 brbr 이번 기회 에 은행권 저 금리 상품 으로 전환 해 보시기 바랍니다 brbr 홍보 성 문자 이나 필요한 한 분 한 분 에게 도움 되고자 합니다 brbr 신청 방법 br 상담 가능 시간 성함 으로 문자 예약 또는 전화 주시 면 상담 가능하십니다 brbr 감사합니다 brbr 은행권 대 환 추가 자금 br 신협 수탁 법인 brbr 상담 전화 brxxxxxxxxxbrbr 해당 되지 않으시거나 거부 원하시는 분 들 거부 라고 회신 하여 주신다면 재 발송 않도록 하겠습니다 번호 의 오류 나 전산 의 실수 있을 수 있 사오니 양해 부탁드립니다 brbr 무료 수신 거부 xxxxxxxxxbodyhtml 광고 신용협동조합 함께',
#  '광고 xx lt 정확하고 올바른 신용 대출 gt 당 사 상품 의 자격 기준 과 심사 기준 완화 되어 상품 에 대해 고객 님 께 간단하게 상품 정보 전달 드립니다 은행 대출 상품 안내 1 직장인 신용 대출 한도 1억 4000만원 금리 연 397% 자격 자체 등급 과 기업 리스트 에 따라 차등 적용 2 채무 통합 전환 대출 한도 연봉 대비 250% 금리 연 397% 자격 자체 등급 과 기업 리스트 에 따라 차등 적용 3 홀씨 한도 2500만원 금리 연 868% 12% 자격 연 소득 4000만원 이하 고객 대상 으로 자체 등급 에 따라 차등 적용 은행 상품 의 특징 1 당사 거래 전혀 없어도 대출 가능 2 시중 은행 보다 높은 한도 3 자체 등급 으로 판단 하므로 저 신용 자 도 대출 가능 4 부채 많다면 부채 통합 상품 으로 전환 가능 5 원리금 균등 방식 이자 만 납 입하 만기일 시로 전환 가능 6 가상 조회 통해 한도 및 금리 한번 에 확인가능 이런 분 들 께 권 해드립니다 1 이미 시중 은행권 에서 대출 한도 모두 사용 중이 신분 2 기 대출 의 원리금 균등 방식 으로 인해 월납 입금 액 부담스러우 신분 3 총 대출 금액 작으나 대출 건 수가 많아서 관리 안되시는 분 4 이제 라도 대출 로 인한 신용등급 관리 및 상승 에 관심 있으 신분 신용 에 대한 기본 적 인 상식 과 지식 알아야 하는 시대 입니다 최소한 의 지식 본인 알아야 금전 적 손해 보는 일이 없습니다 신청 방법 상담 또는 00시 00분 상담 이라고 답장 보내주시거나 전화 주시 면 친절하고 안전한 상담 으로 도움 드리겠습니다 수신 희망 하지 않으실 경우 에는 거부 라는 답장 주시 면 수신 거부 목록 에 등록 시켜 두 번 다시 발송 되지 않도록 조치 취 해드리겠습니다 무료 거부 xxxxxxxxxnull',
#  '광고 xxxbrbr 광고 믿음 과 가치 로 보답 하는 가치 있는 소비 가치 있는 지출 현 고객 님 들이 선택 한 믿음직한 은행 상품 의 자격 기준 보다 완화 되어 상품 에 대해 고객 님 들께 간단하게 정보 전달 드립니다 신용 관리 천천히 한 고객 님 들의 눈높이 에서 함께 걸어 나가겠습니다 수신 희망 하지 않으실 경우 에는 거부 라는 답장 주시 면 kisa 수신 거부 목록 에 등록 시켜 두 번 다시 발송 되지 않도록 조치 취 해드리겠습니다 신청 방법 xxxxxxxxx 터치 하셔서 문자 로 상담 또는 00시 00분 상담 이라고 답장 보내주시거나 전화 주시 면 친절하고 안전한 상담 으로 도움 드리겠습니다 카카오 톡 상담 서비스 시행 중 citibankloan 친구 추가 후 상담 신청 당 행 상품 의 특징 1 당 행 거래 없으셔도 진행 가능 2 시중 은행권 보다 높은 한도 3 자체 등급 으로 판단 하므로 저 신용 자 도 진행 가능 4 부채 많다면 부채 통합 상품 으로 전환 가능 5 원리금 균등 방식 이자 만 납 입하 만기일 시로 전환 가능 6 가상 조회 통해 한도 및 한 번 에 확인 가능 ?']

# %%
from keras.preprocessing.text import Tokenizer

t = Tokenizer()

t.fit_on_texts(X_train)
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# max_len = max([len(i) for i in X_train])

# %%
x_seq = t.texts_to_sequences(X_train)

# %%
max_len = max([len(i) for i in x_seq])

# %%
max_len
# Out:
# 404

# %%
vocab_size = len(t.word_index)+1
vocab_size
# Out:
# 45165

# %%
t.word_index
# Out:
# {'은행': 1,
#  '에': 2,
#  '의': 3,
#  '올림': 4,
#  '고객': 5,
#  '님': 6,
#  '으로': 7,
#  '대출': 8,
#  '로': 9,
#  '상품': 10,
#  '도': 11,
#  '과': 12,
#  '지점': 13,
#  '입니다': 14,
#  '금리': 15,
#  '한': 16,
#  '장': 17,
#  '가능': 18,
#  '상담': 19,
#  '들': 20,
#  '드립니다': 21,
#  '주말': 22,
#  '내': 23,
#  '되세요': 24,
#  '바랍니다': 25,
#  '에서': 26,
#  '금융': 27,
#  '하루': 28,
#  '행복한': 29,
#  '합니다': 30,
#  '보내세요': 31,
#  '2': 32,
#  '팀': 33,
#  '한도': 34,
#  '수': 35,
#  '1': 36,
#  '신청': 37,
#  '좋은': 38,
#  '까지': 39,
#  '분': 40,
#  '3': 41,
#  '하는': 42,
#  '것': 43,
#  '대': 44,
#  '만': 45,
#  '및': 46,
#  '거부': 47,
#  '마음': 48,
#  '점': 49,
#  'xxxxxxxxx': 50,
#  '전화': 51,
#  '일': 52,
#  '감사': 53,
#  '면': 54,
#  '시간': 55,
#  '오늘': 56,
#  '해': 57,
#  '중': 58,
#  '거래': 59,
#  '통합': 60,
#  '와': 61,
#  '시': 62,
#  '광고': 63,
#  '있습니다': 64,
#  '행복': 65,
#  '신용': 66,
#  '사람': 67,
#  '이용': 68,
#  '감사합니다': 69,
#  '인': 70,
#  '부채': 71,
#  '안내': 72,
#  '하고': 73,
#  '고': 74,
#  '연': 75,
#  '진행': 76,
#  '부탁드립니다': 77,
#  '문자': 78,
#  '있는': 79,
#  '주시': 80,
#  '다': 81,
#  '이상': 82,
#  '금액': 83,
#  '저': 84,
#  '항상': 85,
#  '4': 86,
#  '봄': 87,
#  '사랑': 88,
#  '자': 89,
#  '센터': 90,
#  '적': 91,
#  '때': 92,
#  '안': 93,
#  '전환': 94,
#  '무료': 95,
#  '직장인': 96,
#  '많이': 97,
#  '잘': 98,
#  '수신': 99,
#  '함께': 100,
#  '더': 101,
#  '건강': 102,
#  '이자': 103,
#  '종합': 104,
#  '즐거운': 105,
#  '관리': 106,
#  '추가': 107,
#  '등급': 108,
#  '최대': 109,
#  '시작': 110,
#  '가을': 111,
#  '신용등급': 112,
#  '방법': 113,
#  '신': 114,
#  '연락': 115,
#  '서비스': 116,
#  '나': 117,
#  '카드': 118,
#  '되어': 119,
#  '생각': 120,
#  '기간': 121,
#  '하': 122,
#  '사용': 123,
#  '처럼': 124,
#  '적용': 125,
#  '건': 126,
#  '날씨': 127,
#  '하겠습니다': 128,
#  '날': 129,
#  '요': 130,
#  '꼭': 131,
#  '상환': 132,
#  '자금': 133,
#  '드림': 134,
#  '소득': 135,
#  '따라': 136,
#  '세': 137,
#  '그': 138,
#  '론': 139,
#  '자격': 140,
#  '지': 141,
#  '께': 142,
#  '드리겠습니다': 143,
#  '저희': 144,
#  '하세요': 145,
#  '채무': 146,
#  '에게': 147,
#  '할': 148,
#  '늘': 149,
#  '직원': 150,
#  '방식': 151,
#  '등': 152,
#  '기': 153,
#  '번호': 154,
#  '상승': 155,
#  '희망': 156,
#  '서': 157,
#  '6': 158,
#  '도움': 159,
#  '최고': 160,
#  '원': 161,
#  '안녕하세요': 162,
#  '주': 163,
#  '하시고': 164,
#  '에는': 165,
#  '권': 166,
#  '되시길': 167,
#  '말': 168,
#  '가득한': 169,
#  '하여': 170,
#  '가입': 171,
#  '대상': 172,
#  '부터': 173,
#  '원리금': 174,
#  '리브': 175,
#  '경우': 176,
#  '한주': 177,
#  '최저': 178,
#  '부': 179,
#  '입금': 180,
#  '5월': 181,
#  '꽃': 182,
#  '5': 183,
#  '이번': 184,
#  '환': 185,
#  '됩니다': 186,
#  '드리며': 187,
#  '대리': 188,
#  'vip': 189,
#  '우대': 190,
#  '매우': 191,
#  '제': 192,
#  '달': 193,
#  '햇살': 194,
#  '조건': 195,
#  '보다': 196,
#  '차등': 197,
#  '바람': 198,
#  '확인': 199,
#  '기원': 200,
#  '또는': 201,
#  '기준': 202,
#  '차장': 203,
#  '가족': 204,
#  '자체': 205,
#  '매': 206,
#  '후': 207,
#  '대비': 208,
#  '은행권': 209,
#  '계장': 210,
#  '접수': 211,
#  '조회': 212,
#  '따뜻한': 213,
#  '없이': 214,
#  '우리': 215,
#  '하지': 216,
#  '사업자': 217,
#  '된': 218,
#  '되는': 219,
#  '업무': 220,
#  '위': 221,
#  '균등': 222,
#  '4월': 223,
#  '지원': 224,
#  '정부': 225,
#  '수수료': 226,
#  '기분': 227,
#  '본': 228,
#  '이라고': 229,
#  '기존': 230,
#  '6월': 231,
#  '증시': 232,
#  '담보': 233,
#  '개인': 234,
#  '새해': 235,
#  '모두': 236,
#  '내용': 237,
#  '에도': 238,
#  '방문': 239,
#  '혜택': 240,
#  '가능합니다': 241,
#  '현금': 242,
#  '많은': 243,
#  '당': 244,
#  '여유': 245,
#  '해주셔서': 246,
#  '저녁': 247,
#  '모든': 248,
#  '신분': 249,
#  '동의': 250,
#  '소중한': 251,
#  '최근': 252,
#  '가득': 253,
#  '답장': 254,
#  '하늘': 255,
#  '번': 256,
#  '납': 257,
#  '비': 258,
#  '3월': 259,
#  '기업': 260,
#  '웃음': 261,
#  '계절': 262,
#  '아침': 263,
#  '무': 264,
#  '여름': 265,
#  '대한': 266,
#  '사': 267,
#  '보증': 268,
#  '이나': 269,
#  '한번': 270,
#  '개월': 271,
#  '2018년': 272,
#  '추천': 273,
#  '전': 274,
#  '신규': 275,
#  '금': 276,
#  '차': 277,
#  '일이': 278,
#  '우동': 279,
#  '계좌': 280,
#  '포인트': 281,
#  '마무리': 282,
#  '감기': 283,
#  '관련': 284,
#  '다시': 285,
#  '개': 286,
#  '높은': 287,
#  '주세요': 288,
#  '발송': 289,
#  '지금': 290,
#  '연봉': 291,
#  '5년': 292,
#  '현재': 293,
#  '하락': 294,
#  '언제': 295,
#  '인해': 296,
#  '되지': 297,
#  '새': 298,
#  '1억': 299,
#  '마감': 300,
#  '여': 301,
#  '연금': 302,
#  '1년': 303,
#  '낮은': 304,
#  '하시는': 305,
#  '하실': 306,
#  '행': 307,
#  '못': 308,
#  '마지막': 309,
#  '성': 310,
#  '만기': 311,
#  '이다': 312,
#  '속': 313,
#  '문의': 314,
#  '최': 315,
#  '처리': 316,
#  '판단': 317,
#  '해드립니다': 318,
#  '최선': 319,
#  '향기': 320,
#  '게': 321,
#  '바로': 322,
#  '당신': 323,
#  '가장': 324,
#  '기회': 325,
#  '시중': 326,
#  '미소': 327,
#  '등록': 328,
#  '될': 329,
#  '해드리겠습니다': 330,
#  '삶': 331,
#  '주셔서': 332,
#  '2017년': 333,
#  '래': 334,
#  '않도록': 335,
#  '통해': 336,
#  '동': 337,
#  '월': 338,
#  '때문': 339,
#  '분들': 340,
#  '라고': 341,
#  '겨울': 342,
#  '하시면': 343,
#  '영업': 344,
#  '인생': 345,
#  '준비': 346,
#  '친구': 347,
#  '행복하세요': 348,
#  '되었습니다': 349,
#  '새로운': 350,
#  '판매': 351,
#  '유의': 352,
#  '맞이': 353,
#  '기쁨': 354,
#  '양해': 355,
#  '9월': 356,
#  '7월': 357,
#  '하셔서': 358,
#  '연휴': 359,
#  '만족도': 360,
#  '보내시길': 361,
#  '11월': 362,
#  '서류': 363,
#  '감소': 364,
#  '눈': 365,
#  '출시': 366,
#  '납부': 367,
#  '인사': 368,
#  '큰': 369,
#  '재': 370,
#  '가상': 371,
#  '보내': 372,
#  '아름다운': 373,
#  '특징': 374,
#  '이제': 375,
#  '위해': 376,
#  '상': 377,
#  '시기': 378,
#  '조심하시고': 379,
#  '힘': 380,
#  '시켜': 381,
#  '매월': 382,
#  '한해': 383,
#  '라는': 384,
#  '보세요': 385,
#  '복': 386,
#  '기운': 387,
#  '두': 388,
#  '되고': 389,
#  '정보': 390,
#  '일만': 391,
#  '노력': 392,
#  '하며': 393,
#  '세상': 394,
#  '더욱': 395,
#  '엔': 396,
#  '자산': 397,
#  '하나': 398,
#  'pt': 399,
#  '연체': 400,
#  '내일': 401,
#  '앞': 402,
#  '자동': 403,
#  '간': 404,
#  '같은': 405,
#  '이벤트': 406,
#  '추석': 407,
#  '더위': 408,
#  '멋진': 409,
#  '8월': 410,
#  '읽어': 411,
#  '만기일': 412,
#  '상관없이': 413,
#  '출금': 414,
#  '여러': 415,
#  '연장': 416,
#  '수가': 417,
#  '마시고': 418,
#  '스타': 419,
#  '적금': 420,
#  '없습니다': 421,
#  '과장': 422,
#  '즐겁고': 423,
#  '주신다면': 424,
#  '영향': 425,
#  '조치': 426,
#  '12월': 427,
#  '편안한': 428,
#  '아니라': 429,
#  '명절': 430,
#  '금요일': 431,
#  '해당': 432,
#  '예금': 433,
#  '내는': 434,
#  '부담': 435,
#  '관심': 436,
#  '소': 437,
#  '몸': 438,
#  '변경': 439,
#  'xxxxxxxx': 440,
#  '행운': 441,
#  '받으세요': 442,
#  '리스트': 443,
#  '만들어': 444,
#  '진심': 445,
#  '봄날': 446,
#  '이체': 447,
#  '2월': 448,
#  '앱': 449,
#  '자신': 450,
#  '85': 451,
#  '혹시': 452,
#  '하기': 453,
#  '10월': 454,
#  '만족': 455,
#  '통장': 456,
#  '환율': 457,
#  '드리고': 458,
#  '있으시면': 459,
#  '같습니다': 460,
#  '오후': 461,
#  '조': 462,
#  '하시길': 463,
#  '길': 464,
#  '업체': 465,
#  '이런': 466,
#  '참': 467,
#  '통화': 468,
#  '없는': 469,
#  '조금': 470,
#  '라도': 471,
#  '중도': 472,
#  '빠른': 473,
#  '21': 474,
#  '든지': 475,
#  '너무': 476,
#  '순간': 477,
#  '투자': 478,
#  '로운': 479,
#  '법인': 480,
#  '사항': 481,
#  '활짝': 482,
#  '국내': 483,
#  '시원한': 484,
#  '작으나': 485,
#  '문': 486,
#  '없음': 487,
#  '1월': 488,
#  '원하시는': 489,
#  '20': 490,
#  '끝': 491,
#  '시장': 492,
#  '발생': 493,
#  '완화': 494,
#  '있다면': 495,
#  '환전': 496,
#  '라운지': 497,
#  '300': 498,
#  '대해': 499,
#  '다중': 500,
#  '니': 501,
#  '미국': 502,
#  '좋겠습니다': 503,
#  '행복한주말': 504,
#  '알': 505,
#  '든': 506,
#  '언제나': 507,
#  '배': 508,
#  '뱅킹': 509,
#  '별': 510,
#  '예약': 511,
#  '제공': 512,
#  '홀씨': 513,
#  '가지': 514,
#  '행복하고': 515,
#  '선물': 516,
#  '카톡': 517,
#  '동안': 518,
#  '형': 519,
#  '한국': 520,
#  '예정': 521,
#  '보내시기': 522,
#  '90': 523,
#  '있어': 524,
#  '다른': 525,
#  '어제': 526,
#  '조심하세요': 527,
#  '절감': 528,
#  '타': 529,
#  '통': 530,
#  '있다': 531,
#  '남': 532,
#  '이하': 533,
#  '액': 534,
#  '자만': 535,
#  '벌써': 536,
#  '가슴': 537,
#  '지수': 538,
#  '아': 539,
#  '정기예금': 540,
#  '본인': 541,
#  '오전': 542,
#  '금일': 543,
#  '꿈': 544,
#  '화': 545,
#  '펀드': 546,
#  '칭찬': 547,
#  '원금': 548,
#  '10': 549,
#  '필': 550,
#  '신분증': 551,
#  '하게': 552,
#  '가득하시길': 553,
#  '줄여': 554,
#  '변동': 555,
#  '전담': 556,
#  '있': 557,
#  '모습': 558,
#  '주부': 559,
#  '필요한': 560,
#  '인한': 561,
#  '채무자': 562,
#  '명': 563,
#  '실수': 564,
#  '총': 565,
#  '이고': 566,
#  '가정': 567,
#  '참고': 568,
#  '않으실': 569,
#  '곳': 570,
#  '만큼': 571,
#  '추억': 572,
#  '회신': 573,
#  '역': 574,
#  '가능하십니다': 575,
#  '이후': 576,
#  '향': 577,
#  '오류': 578,
#  '누구': 579,
#  '실적': 580,
#  '글': 581,
#  '또': 582,
#  '바라며': 583,
#  '국': 584,
#  '지식': 585,
#  '증명': 586,
#  '급': 587,
#  '않습니다': 588,
#  '3000만원': 589,
#  '송금': 590,
#  '계속': 591,
#  '급여': 592,
#  '일시': 593,
#  '퇴직': 594,
#  '드려요': 595,
#  '출': 596,
#  '12': 597,
#  '계획': 598,
#  '활기찬': 599,
#  '프리랜서': 600,
#  '지만': 601,
#  '되': 602,
#  '먼저': 603,
#  '하시기': 604,
#  '1억원': 605,
#  '휴가': 606,
#  '예쁜': 607,
#  '또한': 608,
#  '마다': 609,
#  '정말': 610,
#  '유효': 611,
#  '정도': 612,
#  '한가위': 613,
#  '온': 614,
#  '고민': 615,
#  '무더위': 616,
#  '보는': 617,
#  '월요일': 618,
#  '즐겁게': 619,
#  '하면': 620,
#  '건강한': 621,
#  '께서': 622,
#  '중앙': 623,
#  '하신': 624,
#  '당사': 625,
#  '보험': 626,
#  '이내': 627,
#  '있도록': 628,
#  '필요': 629,
#  '가산': 630,
#  '이신': 631,
#  '네': 632,
#  '가능한': 633,
#  '거치': 634,
#  '있을': 635,
#  '보내시고': 636,
#  '생활': 637,
#  '아파트': 638,
#  '해주세요': 639,
#  '며': 640,
#  '첫': 641,
#  '완료': 642,
#  '풍': 643,
#  '메이트': 644,
#  '사업': 645,
#  '줄': 646,
#  '대로': 647,
#  '웃는': 648,
#  '살': 649,
#  '듯': 650,
#  '알아야': 651,
#  '함': 652,
#  '되며': 653,
#  '약속': 654,
#  '보시': 655,
#  '라': 656,
#  '그리고': 657,
#  '아래': 658,
#  'kospi': 659,
#  '매일': 660,
#  '수령': 661,
#  '우선': 662,
#  '주시거나': 663,
#  '1만': 664,
#  '부결': 665,
#  '설치': 666,
#  '받아': 667,
#  '새롭게': 668,
#  '선택': 669,
#  '보': 670,
#  '과세': 671,
#  '입력': 672,
#  '메세지': 673,
#  '환절기': 674,
#  '미세먼지': 675,
#  '부탁드려요': 676,
#  '자세한': 677,
#  '제목': 678,
#  '올': 679,
#  '여부': 680,
#  '소리': 681,
#  '주요': 682,
#  '행복하게': 683,
#  '제한': 684,
#  '찾아': 685,
#  '7등': 686,
#  '사실': 687,
#  '넘치는': 688,
#  '요즘': 689,
#  '화이팅': 690,
#  '않고': 691,
#  'p': 692,
#  '작은': 693,
#  '지속': 694,
#  '풍요': 695,
#  '우대금리': 696,
#  '있게': 697,
#  '돈': 698,
#  '미': 699,
#  '용도': 700,
#  '많아서': 701,
#  '외국인': 702,
#  '발급': 703,
#  '분할': 704,
#  '봅니다': 705,
#  '예': 706,
#  '친절히': 707,
#  '소식': 708,
#  '50': 709,
#  '소망': 710,
#  '안전한': 711,
#  '돌': 712,
#  '세액': 713,
#  '포함': 714,
#  '씩': 715,
#  '기억': 716,
#  '달력': 717,
#  '가득하세요': 718,
#  '거': 719,
#  '혹은': 720,
#  '승인': 721,
#  '장기': 722,
#  '호': 723,
#  '심의': 724,
#  '올해': 725,
#  '자리': 726,
#  '봄비': 727,
#  '응원': 728,
#  '쿠폰': 729,
#  '반': 730,
#  '주는': 731,
#  '자유롭게': 732,
#  '잦은': 733,
#  '성함': 734,
#  '이미': 735,
#  '많아': 736,
#  '폭': 737,
#  '찬': 738,
#  '심사': 739,
#  '죄송합니다': 740,
#  '식': 741,
#  '검색': 742,
#  '이라는': 743,
#  '13': 744,
#  '음': 745,
#  '품': 746,
#  '산': 747,
#  '궁금하신': 748,
#  '65': 749,
#  '없어도': 750,
#  '지연': 751,
#  '출발': 752,
#  '인연': 753,
#  '일상': 754,
#  '전혀': 755,
#  '주거': 756,
#  '않는': 757,
#  '지급': 758,
#  '걱정': 759,
#  '입시': 760,
#  '약': 761,
#  '공제': 762,
#  '잠시': 763,
#  '긍정': 764,
#  '알림': 765,
#  'irp': 766,
#  '다양한': 767,
#  '용인': 768,
#  '내어': 769,
#  '45': 770,
#  '전산': 771,
#  '말씀': 772,
#  '보유': 773,
#  '중국': 774,
#  '나무': 775,
#  '4천만원': 776,
#  '재직': 777,
#  '될수': 778,
#  '이렇게': 779,
#  '시로': 780,
#  '기록': 781,
#  '증명서': 782,
#  '00분': 783,
#  '상담사': 784,
#  '등본': 785,
#  '부탁': 786,
#  '잊지': 787,
#  '뜻': 788,
#  '나를': 789,
#  '남은': 790,
#  '중이': 791,
#  '8': 792,
#  '한다': 793,
#  '00시': 794,
#  '친절하고': 795,
#  '오': 796,
#  '충전': 797,
#  '기본': 798,
#  '권유': 799,
#  '않은': 800,
#  '천': 801,
#  '순': 802,
#  '하실수': 803,
#  '단': 804,
#  '불입': 805,
#  '이라': 806,
#  '다음': 807,
#  '학생': 808,
#  'liiv': 809,
#  '많다면': 810,
#  '어떤': 811,
#  '할인': 812,
#  '사오니': 813,
#  '예상': 814,
#  '입출금': 815,
#  '건강하시고': 816,
#  '다해': 817,
#  '보내주시거나': 818,
#  '축하': 819,
#  '개편': 820,
#  '드리는': 821,
#  '필요할': 822,
#  '교차': 823,
#  '되시기': 824,
#  '내리는': 825,
#  '움': 826,
#  '모시겠습니다': 827,
#  '되실': 828,
#  '계': 829,
#  '인터넷': 830,
#  '되고자': 831,
#  '많으니': 832,
#  '시대': 833,
#  '추운': 834,
#  '치': 835,
#  '열심히': 836,
#  '행사': 837,
#  '어느': 838,
#  '채': 839,
#  '잇': 840,
#  '신용카드': 841,
#  '않으시거나': 842,
#  '250': 843,
#  '시행': 844,
#  '깊은': 845,
#  '물': 846,
#  '즐거운주말': 847,
#  '5천만원': 848,
#  '하므로': 849,
#  '납입': 850,
#  '이란': 851,
#  '맑은': 852,
#  '동지점': 853,
#  '고생': 854,
#  '바': 855,
#  '기도': 856,
#  '직접': 857,
#  '기준금리': 858,
#  '기관': 859,
#  '어렵다면': 860,
#  '푸른': 861,
#  '홍콩': 862,
#  '모바일': 863,
#  '수탁': 864,
#  '월간': 865,
#  '뿐': 866,
#  '효과': 867,
#  '달러': 868,
#  '전달': 869,
#  '손': 870,
#  '벚꽃': 871,
#  '기를': 872,
#  '찾아주셔서': 873,
#  '5000만원': 874,
#  '등록증': 875,
#  '받으시면': 876,
#  '보내고': 877,
#  '조사': 878,
#  '에서도': 879,
#  '했습니다': 880,
#  '주의': 881,
#  '초록': 882,
#  '되시는': 883,
#  '편하게': 884,
#  '더운': 885,
#  '해야': 886,
#  '서로': 887,
#  '으로도': 888,
#  '주도': 889,
#  '가끔': 890,
#  '시스템': 891,
#  '정': 892,
#  '한잔': 893,
#  '추위': 894,
#  '국민': 895,
#  '있고': 896,
#  '주민등록': 897,
#  '스마트': 898,
#  '해서': 899,
#  '같이': 900,
#  '되겠습니다': 901,
#  '우수': 902,
#  '전망': 903,
#  '대부': 904,
#  '주택': 905,
#  '적립': 906,
#  '건강하고': 907,
#  '30만원': 908,
#  '공': 909,
#  '길이': 910,
#  '단풍': 911,
#  '몇': 912,
#  '이며': 913,
#  '이네': 914,
#  '10년': 915,
#  '있으니': 916,
#  '하지만': 917,
#  '입하': 918,
#  '목록': 919,
#  '납입액': 920,
#  '간단하게': 921,
#  '급이내의': 922,
#  '이지만': 923,
#  '이라도': 924,
#  '스스로': 925,
#  'o': 926,
#  '얼굴': 927,
#  '30': 928,
#  '빛': 929,
#  '불': 930,
#  '무더운': 931,
#  '휴식': 932,
#  '청계': 933,
#  '탄현': 934,
#  '누군가': 935,
#  '보면': 936,
#  '실행': 937,
#  '사금융': 938,
#  '양': 939,
#  '잎': 940,
#  '플레이스토어': 941,
#  '불편': 942,
#  '확대': 943,
#  '준법': 944,
#  '상쾌한': 945,
#  '많아도': 946,
#  '알려': 947,
#  '200': 948,
#  '안녕하십니까': 949,
#  '무엇': 950,
#  '해외': 951,
#  '취': 952,
#  '공사': 953,
#  '23': 954,
#  '사이': 955,
#  '바쁜': 956,
#  '있으며': 957,
#  '감시인': 958,
#  '즐거움': 959,
#  '무역': 960,
#  '평균': 961,
#  '눌러주시면': 962,
#  '라면': 963,
#  '민지원': 964,
#  '목': 965,
#  '2천': 966,
#  '여신': 967,
#  '근로자': 968,
#  '아직': 969,
#  '이름': 970,
#  '김': 971,
#  '따스한': 972,
#  '든든한': 973,
#  '인상': 974,
#  '대표': 975,
#  '곁': 976,
#  '했다': 977,
#  '이유': 978,
#  '서민': 979,
#  '따른': 980,
#  '어플': 981,
#  '군': 982,
#  '금전': 983,
#  '바쁘신': 984,
#  '건수': 985,
#  '일반': 986,
#  '우려': 987,
#  '옥련동': 988,
#  '핵심': 989,
#  '상황': 990,
#  '2019년': 991,
#  '거리': 992,
#  '금년': 993,
#  '아닌': 994,
#  '한마디': 995,
#  '창구': 996,
#  '직': 997,
#  '중인': 998,
#  '조정': 999,
#  '297': 1000,
#  ...}

# %%
len(x_seq)
# Out:
# 26500

# %%
from keras.preprocessing.sequence import pad_sequences 
x_pad_seq = pad_sequences(x_seq,maxlen=max_len)

# %%
x_pad_seq[:5]
# Out:
# array([[   0,    0,    0, ...,   99,   47,   50],
#        [   0,    0,    0, ...,   95,   47,   50],
#        [   0,    0,    0, ...,   63, 4756,  100],
#        [   0,    0,    0, ...,   95,   47, 4939],
#        [   0,    0,    0, ...,    2,  199,   18]], dtype=int32)

# %% [markdown]
# # word2vec train데이터로만 학습

# %%
# train.head()
# Out:
#                                                 text  smishing
# 0             q()p  -(((((-메리 크리스마스 !많이 웃으세요  미래가...         0
# 1           -()-            ()XXX 고객님복 많이 받으세요즐거운...         0
# 2           XXX 고객님메리크리스마스!!즐거운 성탄절이다가 왔습니다.가족친지분...         0
# 3          겨울    사랑하는 사람아우리에게 겨울이 없다면무엇으로 따뜻한 포옹이...         0
# 4          근 하 신 년  XXX 고객님께!설레는 마음으로 시작했던 2017년도...         0

# %%
# pat = re.compile('[^가-힣0-9a-z ]')
# a= train['text'].apply(lambda x : pat.sub('',x.lower()))
# train_wv_doc = [tokenizer.nouns(x) for x in a]

# %%
# len(train_wv_doc)
# Out:
# 295945

# %%
# a[0]
# Out:
# 'xxx은행성산xxx팀장입니다행복한주말되세요'

# %%
train_wv_doc[:2]
# Out:
# [['행성', '산', '팀장', '행복', '주말'], ['오늘', '하루', '시작', '은행', '진월동', '라운지']]

# %%
from gensim.models import Word2Vec
word2vec_train = Word2Vec(train_wv_doc, size=200, window=5, min_count=5, workers=4, sg=1)

# %%
t.fit_on_texts(train_wv_doc)

# %%
vocab_size = len(t.word_index)+1
vocab_size
# Out:
# 17806

# %% [markdown]
# # ---------------------------------------------

# %%
vocab_size = 10000+1

# %%
import gensim

model = gensim.models.Word2Vec.load('/content/drive/My Drive/tabditor/소스코드/기능1. 문맥에 맞는 단어 추천/ko.bin')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
import numpy as np
embedding_matrix = np.zeros((vocab_size,200))

# %%
def get_vector(word):
    if word in model:
        return model[word]
    else:
        return None

# %%
for word, i in t.word_index.items(): # 훈련 데이터의 단어 집합에서 단어와 정수 인덱스를 1개씩 꺼내온다.
    temp = get_vector(word) # 단어(key) 해당되는 임베딩 벡터의 300개의 값(value)를 임시 변수에 저장
    if temp is not None: # 만약 None이 아니라면 임베딩 벡터의 값을 리턴받은 것이므로
        embedding_matrix[i] = temp
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import tensorflow as tf

class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = Dense(units)
    self.W2 = Dense(units)
    self.V = Dense(1)

  def call(self, values, query): # 단, key와 value는 같음
    # hidden shape == (batch_size, hidden size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden size)
    # we are doing this to perform addition to calculate the score
    hidden_with_time_axis = tf.expand_dims(query, 1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.V(tf.nn.tanh(
        self.W1(values) + self.W2(hidden_with_time_axis)))

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * values
    context_vector = tf.reduce_sum(context_vector, axis=1)
    # context_vector = tf.clip_by_value(context_vector)
    # print(attention_weights)

    return context_vector, attention_weights

# %%
# model1.add(Embedding(vocab_size,200,weights=[embedding_matrix],input_length=max_len,trainable=False))
# # model1.add(Embedding(vocab_size,200)) 성능 개같음 
# model1.add(LSTM(128,dropout=0.2,return_sequences=True))
# model1.add(LSTM(128,dropout=0.2))
# model1.add(Dense(1,activation='sigmoid'))

# %% [markdown]
# inputs=Input(shape=(max_len,),dtype='int32')
# Embedding(vocab_size,200,weights=[embedding_matrix])(inputs)

# %%
# max_len= 487

# %%
from tensorflow.keras.layers import Dense, Embedding, Bidirectional, LSTM, Concatenate, BatchNormalization
from tensorflow.keras import Input, Model,Sequential
from tensorflow.keras import optimizers
# import os

# model1 = Sequential()
# model1.add(Embedding(vocab_size,200,weights=[embedding_matrix],input_length=max_len,trainable=False))
inputs=Input(shape=(max_len,),dtype='int32')
embedding_seq= Embedding(vocab_size,200,input_length=max_len)(inputs)
lstm, forward_h, forward_c, backward_h, backward_c = Bidirectional \
(LSTM(128,dropout=0.3,return_sequences=True,return_state=True,recurrent_activation='relu',recurrent_initializer='glorot_uniform'))(embedding_seq)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
state_h = Concatenate()([forward_h, backward_h]) # 은닉 상태
state_c = Concatenate()([forward_c, backward_c]) # 셀 상태

# %%
attention = BahdanauAttention(128) # 가중치 크기 정의
context_vector, attention_weights = attention(lstm, state_h)
hidden = BatchNormalization()(context_vector)

# %%
output = Dense(1, activation='sigmoid')(hidden)
model1 = Model(inputs=inputs, outputs=output)

# %%
Adam = optimizers.Adam(lr=0.1e-7,clipnorm=1.)
#, clipnorm=1.

# %%
(pd.Series(Y_train)).value_counts()
# Out:
# 0    25000
# 1     1500
# dtype: int64

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
ck = ModelCheckpoint('bilstm_no_w2vec_50epoch.h5',save_weights_only=True,verbose=1)

# %%
model1.compile(optimizer=Adam,loss='binary_crossentropy',metrics=['acc'])
model1.fit(x_pad_seq,Y_train,batch_size=256,validation_split=0.1,epochs= 50,callbacks=[ck])
# Out:
# Train on 23850 samples, validate on 2650 samples
# Epoch 1/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5055
# Epoch 00001: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 85s 4ms/sample - loss: 0.6952 - acc: 0.5056 - val_loss: 0.7239 - val_acc: 0.0204
# Epoch 2/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5066
# Epoch 00002: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 83s 3ms/sample - loss: 0.6953 - acc: 0.5067 - val_loss: 0.7230 - val_acc: 0.0238
# Epoch 3/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6954 - acc: 0.5082
# Epoch 00003: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6954 - acc: 0.5081 - val_loss: 0.7238 - val_acc: 0.0208
# Epoch 4/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5071
# Epoch 00004: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6953 - acc: 0.5070 - val_loss: 0.7242 - val_acc: 0.0196
# Epoch 5/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5112
# Epoch 00005: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6953 - acc: 0.5112 - val_loss: 0.7239 - val_acc: 0.0204
# Epoch 6/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5065
# Epoch 00006: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 85s 4ms/sample - loss: 0.6953 - acc: 0.5066 - val_loss: 0.7247 - val_acc: 0.0181
# Epoch 7/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5078
# Epoch 00007: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 85s 4ms/sample - loss: 0.6952 - acc: 0.5078 - val_loss: 0.7250 - val_acc: 0.0166
# Epoch 8/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5087
# Epoch 00008: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6952 - acc: 0.5086 - val_loss: 0.7249 - val_acc: 0.0170
# Epoch 9/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5087
# Epoch 00009: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6952 - acc: 0.5087 - val_loss: 0.7243 - val_acc: 0.0189
# Epoch 10/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6954 - acc: 0.5085
# Epoch 00010: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 85s 4ms/sample - loss: 0.6954 - acc: 0.5084 - val_loss: 0.7242 - val_acc: 0.0192
# Epoch 11/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6952 - acc: 0.5035
# Epoch 00011: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6952 - acc: 0.5035 - val_loss: 0.7241 - val_acc: 0.0200
# Epoch 12/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6950 - acc: 0.5080
# Epoch 00012: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 84s 4ms/sample - loss: 0.6950 - acc: 0.5079 - val_loss: 0.7251 - val_acc: 0.0162
# Epoch 13/50
# 23808/23850 [============================>.] - ETA: 0s - loss: 0.6953 - acc: 0.5067
# Epoch 00013: saving model to bilstm_no_w2vec_50epoch.h5
# 23850/23850 [==============================] - 85s 4ms/sample - loss: 0.6953 - acc: 0.5068 - val_loss: 0.7247 - val_acc: 0.0177
# Epoch 14/50
# 11776/23850 [=============>................] - ETA: 41s - loss: 0.6951 - acc: 0.5076

# %%
model1.load_weights('bilstm_no_w2vec_50epoch.h5')

# %%
ls ../../
# Out:
# '일지 및 이슈'/   작업/   데이터/   모델링/   실험용.ipynb   submissions/

# %%
model1.save_weights('../../data30000_lstm_2layer.h5')

# %%
x_test =[]

for lwords in test_doc:
    temp=[]
    for x in get_couple(lwords[0]):
        # if len(x) >1:
        temp.append(x)
    x_test.append(' '.join(temp))

# %%
x_test[0]
# Out:
# '고객 님 안녕 하 세요 새롭 게 시작 하 한 주 행복 가득 하 시 길 기원 합니다 지난주 글로벌 증시 파월 미 연준 의장 통화 정책 에 대해 완화 적 인 태도 변화 보인 것 주초 투자 심리 개선 으로 이어지 며 큰 폭 상승 마감 했 습니다 더불 어 미 중 차관 급 무역 협상 순조 롭 게 진행 된 점 도 긍정 적 었 습니다 원 달러 환율 주간 75 원 으로 하락 하 가운데 외국인 투자자 의 국내 증시 순 매수 규모 8 천억 상회 하 며 수급 개선 된 점 도 주목 해 볼 필요 있 습니다 금주 시장 미국 금융 주 실적 발표 시작 으로 본격 적 인 실적 시즌 에 진입 하 게 됩니다 지난주 애플 삼성전자 등 주요 기업 들 의 1 분기 실적 전망 하향 조정 있 었 던 점 참고 한다면 올해 글로벌 성장 둔화 기조 속 에서 기업 들 의 순익 감소 추이 관심 있 게 살펴보 실 필요 있 어 보입니다 주 후반 에 브렉 시트 영국 하원 표결 예정 되 어 있 습니다 추워진 날씨 에 건강 유의 하 시 고 좋 한 주 되 세요 감사 합니다 은행 송도 센터 올림'

# %%
t.fit_on_texts(x_test)

x_test_seq = t.texts_to_sequences(x_test)

x_test_pad_seq = pad_sequences(x_test_seq, maxlen=max_len)

# %%
y_pred = model1.predict(x_test_pad_seq)

# %%
sub = pd.read_csv('/content/drive/My Drive/제목없는 폴더/dacon_folder/submission_제출양식.csv')

# %%
sub['smishing'] = y_pred

# %%
sub
# Out:
#           id  smishing
# 0     340000  0.000032
# 1     340001  0.000259
# 2     340002  0.000094
# 3     340003  0.000083
# 4     340004  0.025517
# ...      ...       ...
# 1621  341621  0.000809
# 1622  341622  0.000040
# 1623  341623  0.000011
# 1624  341624  0.000008
# 1625  341625  0.000035
#
# [1626 rows x 2 columns]

# %%
sub.to_csv('../../submissions/lstm_with_word2vec_trainingdata30000_2layer.csv',index=False)

# %%
sub
# Out:
#           id  smishing
# 0     340000  0.000032
# 1     340001  0.000259
# 2     340002  0.000094
# 3     340003  0.000083
# 4     340004  0.025517
# ...      ...       ...
# 1621  341621  0.000809
# 1622  341622  0.000040
# 1623  341623  0.000011
# 1624  341624  0.000008
# 1625  341625  0.000035
#
# [1626 rows x 2 columns]

# %%
# stopwords = ['xxx', '.', '을', '를', '이', '가', '-', '(', ')', ':', '!', '?', ')-', '.-', 'ㅡ', 'xxxxxx', '..', '.(', '은', '는'] #필요없는 단어 리스트

# def get_couple(words):
#     global stopwords
#     words = [i for i in words if i[0] not in stopwords]
#     for i in range(len(words)-1):
#         # print(words[i][0])
#         yield words[i][0], words[i+1][0]
#         # words[i][0]은 stopwords로 걸러진 단어들

# %%
for x,y in get_couple(train_doc[0][0]):
    print(x,y)

# %%
# 코드 이해용
# for i in train_doc[:1]:
#     # print(i[0])
#     for j in i[0]:
#         # print(j[0])
#         if j[0] in stopwords:
#             print(j[0])

# %%
X_train, Y_train = [],[]

for lwords in train_doc:
    Y_train.append(lwords[1])

    temp = []

    for x,y in get_couple(lwords[0]):
        temp.append('{}.{}'.format(x,y))

    X_train.append(' '.join(temp))

# %%
X_train[:10]
# Out:
# ['광고.S S.B B.I I.안녕 안녕.하 하.세요 세요.하루하루 하루하루.힘든 힘든.업무 업무.와 와.스트레스 스트레스.에 에.고생 고생.많 많.으십니다 으십니다.여유 여유.시간 시간.내 내.어 어.읽 읽.어 어.주 주.신다면 신다면.도움 도움.되 되.실 실.거 거.라 라.생각 생각.되 되.어 어.보내 보내.드립니다 드립니다.2017 2017.년 년.하반기 하반기.정부 정부.지원 지원.상품 상품.개편 개편.되 되.어 어.안 안.내 내.드립니다 드립니다.금년 금년.낮 낮.금리 금리.로 로.대출금 대출금.이용 이용.하 하.실 실.수 수.있 있.마지막 마지막.기회 기회.입니다 입니다.고민 고민.하 하.지 지.마시 마시.고 고.전화 전화.주세 주세.요 요.본 본.상품 상품.서민 서민.지원 지원.대출 대출.로 로.정부 정부.에서 에서.지원 지원.하 하.고 고.S S.B B.I I.에서 에서.판매 판매.하 하.대출 대출.상품 상품.입니다 입니다.상품 상품.특징 특징.1 1.무담보 무담보.무 무.보증 보증.무 무.수수료 수수료.2 2.신용 신용.등급 등급.상관없이 상관없이.3 3.최고 최고.한도 한도.90004 90004.최하 최하.금리 금리.4 4.24 24.% %.9 9.89 89.% %.5 5.상환 상환.수수료 수수료.없이 없이.자유 자유.롭 롭.게 게.상환 상환.가능 가능.6 6.기존 기존.대출 대출.저금리 저금리.전환 전환.가능 가능.자격 자격.조건 조건.1 1.만 만.21 21.세 세.65 65.세 세.2 2.직장인 직장인.사업자 사업자.프리랜서 프리랜서.주부 주부.3 3.최근 최근.부결 부결.자 자.다중 다중.채무자 채무자.가능 가능.신청 신청.기간 기간.9 9.월 월.29 29.일 일.마감 마감.접수 접수.자 자.많 많.으니 으니.빠른 빠른.신청 신청.바랍니다 바랍니다.신청 신청.방법 방법.상담 상담.가능 가능.하 하.실 실.때 때.카톡 카톡.추가 추가.또는 또는.전화 전화.주 주.시 시.면 면.상담 상담.가능 가능.하 하.십니다 십니다.상담 상담.전화 전화.카카오톡 카카오톡.문 문.의 의.아이디 아이디.bb bb.745 745.입니다 입니다.해당 해당.되 되.지 지.않 않.으시 으시.거나 거나.거부 거부.원하 원하.시 시.분 분.들 들.거부 거부.라고 라고.회신 회신.하 하.여 여.주 주.신다면 신다면.재 재.발송 발송.않 않.도록 도록.하 하.겠 겠.습니다 습니다.번호 번호.의 의.오류 오류.나 나.전산 전산.의 의.실수 실수.있 있.수 수.있 있.사오니 사오니.양해 양해.부탁 부탁.드립니다 드립니다.무료 무료.거부 거부.광고 광고.S S.B B.I',
#  '광고.koreaXXX koreaXXX.고금리 고금리.부채 부채.가계 가계.병들 병들.게 게.합니다 합니다.무료 무료.재무 재무.포토 포토.폴리오 폴리오.신청 신청.하 하.고 고.미래 미래.플랜 플랜.설계 설계.해 해.보 보.세요 세요.신용 신용.등급 등급.관리 관리.팀 팀.에서 에서.등급 등급.올릴 올릴.수 수.있 있.tip tip.알려 알려.드립니다 드립니다.1 1.주 주.거래 거래.은행 은행.만들 만들.기 기.은행 은행.자사 자사.거래 거래.실적 실적.많 많.고객 고객.에게 에게.좋 좋.평점 평점.합니다 합니다.2 2.일시불 일시불.사용 사용.지속 지속.적 적.인 인.할부 할부.누적 누적.부채 부채.증가 증가.로 로.인식 인식.등급 등급.에 에.부정 부정.적 적.요인 요인.3 3.적정 적정.카드 카드.사용 사용.한도 한도.에 에.가깝 가깝.게 게.쓰 쓰.지 지.말 말.고 고.2030 2030.% %.수준 수준.유지 유지.4 4.공과금 공과금.성실 성실.납부 납부.하 하.기 기.각종 각종.공과금 공과금.6 6.개월 개월.이상 이상.성실히 성실히.납부 납부.하 하.면 면.가산점 가산점.받 받.아요 아요.5 5.이자 이자.높 높.대출 대출.부터 부터.갚 갚.자 자.대출금 대출금.상환 상환.만 만.잘 잘.해도 해도.등급 등급.향상 향상.에 에.도움 도움.됩니다 됩니다.6 6.신용 신용.등급 등급.꾸준히 꾸준히.관리 관리.등급 등급.하락 하락.요인 요인.인 인.연체 연체.하 하.지 지.않 않.기 기.위해 위해.평소 평소.꾸준히 꾸준히.관리 관리.및 및.확인 확인.직장 직장.인 인.안내 안내.금리 금리.연 연.2 2.82 82.%( %(.CD CD.금리 금리.변동 변동.직장 직장.인 인.기준 기준.공무원 공무원.외감 외감.업체 업체.대 대.기업 기업.우대 우대.한도 한도.1 1.억 억.4 4.천만 천만.원 원.까지 까지.일반 일반.업체 업체.개인사 개인사.업장 업장.근로자 근로자.도 도.진행 진행.가능 가능.신용 신용.도와 도와.상관없이 상관없이.자체 자체.등급 등급.으로 으로.판단 판단.거치 거치.상품 상품.만기 만기.대출 대출.연장 연장.으로 으로.매월 매월.내 내.시 시.원리금 원리금.줄일 줄일.수 수.있 있.습니다 습니다.상담 상담.신청 신청.방법 방법.문자 문자.로 로.상담 상담.라고 라고.답장 답장.주 주.시 시.거나 거나.전화 전화.주 주.시 시.면 면.정직 정직.하 하.고 고.친절히 친절히.상담 상담.으로 으로.도움 도움.드릴께요 드릴께요.신용 신용.상담 상담.위한 위한.신용 신용.조회 조회.등급 등급.에 에.영향 영향.미치 미치.지 지.않 않.습니다 습니다.카카오톡 카카오톡.신청 신청.방법 방법.ID ID.citi citi.59 59.아이디 아이디.검색 검색.후 후.친구 친구.추가 추가.후 후.상담 상담.라는 라는.카톡 카톡.남겨 남겨.주 주.세요 세요.빠르 빠르.게 게.답변 답변.드리 드리.겠 겠.습니다 습니다.부채 부채.통합 통합.대출 대출.상 상.품 품.자격 자격.조건 조건.사 사.대 대.보험 보험.가능 가능.한 한.직장 직장.인 인.and and.재직 재직.1 1.년 년.이상 이상.1 1.년 년.미만 미만.도 도.직군 직군.과 과.등급 등급.에 에.따라 따라.가능 가능.할 할.수 수.있 있.습니다 습니다.한도 한도.연봉 연봉.대비 대비.300 300.% %.까지 까지.금리 금리.최저 최저.3 3.%( %(.등급 등급.차등 차등.적용 적용.부채 부채.통합 통합.대출 대출.의 의.요 요.약연 약연.소득 소득.대비 대비.최대 최대.300 300.% %.내신 내신.용 용.등급 등급.7 7.등급 등급.내 내.의 의.직장인 직장인.면 면.카드 카드.론 론.현금 현금.서비스 서비스.사용 사용.잦 잦.분 분.들 들.원리금 원리금.균 균.등 등.방식 방식.이자 이자.만 만.내 내.방식 방식.으로 으로.전환 전환.부채 부채.과다 과다.로 로.인해 인해.추가 추가.진행 진행.어렵 어렵.다면 다면.통합 통합.해 해.드리 드리.겠 겠.습니다 습니다.최근 최근.6 6.개월 개월.간 간.연체 연체.사실 사실.있 있.다면 다면.진행 진행.안 안.됩니다 됩니다.월 월.최대 최대.85 85.% %.정도 정도.이자 이자.절감 절감.월 월.100 100.만 만.원 원.이상 이상.신청 신청.방법',
#  '광고.정확 정확.하 하.고 고.올바른 올바른.신용 신용.대출 대출.저희 저희.은행 은행.이용 이용.해 해.주 주.시 시.고 고.사랑 사랑.해 해.주 주.셔서 셔서.감사 감사.드립니다 드립니다.11 11.월 월.예외 예외.특판 특판.상품 상품.출시 출시.로 로.새롭 새롭.게 게.저렴 저렴.한 한.금리 금리.와 와.높 높.한도 한도.로 로.도움 도움.드리 드리.고자 고자.합니다 합니다.1 1.직장 직장.인 인.신용대 신용대.출한 출한.도 도.1 1.억 억.4000 4000.만 만.원 원.금리 금리.연 연.3 3.97 97.% %.자격 자격.자체 자체.등급 등급.과 과.기업 기업.리스트 리스트.에 에.따라 따라.차등 차등.적용 적용.2 2.채 채.무통 무통.합전 합전.환대 환대.출한 출한.도 도.연봉 연봉.대비 대비.250 250.% %.금리 금리.연 연.3 3.97 97.% %.자격 자격.자체 자체.등급 등급.과 과.기업 기업.리스트 리스트.에 에.따라 따라.차등 차등.적용 적용.3 3.홀 홀.씨 씨.한도 한도.2500 2500.만 만.원 원.금리 금리.연 연.8 8.68 68.% %.12 12.% %.자격 자격.연소 연소.득 득.4000 4000.만 만.원 원.이하 이하.고객 고객.대상 대상.으로 으로.자체 자체.등급 등급.에 에.따라 따라.차등 차등.적용 적용.상품 상품.의 의.특징 특징.1 1.당사 당사.거래 거래.전혀 전혀.없 없.어도 어도.대출 대출.가능 가능.2 2.시중 시중.은행 은행.보다 보다.높 높.한도 한도.3 3.자체 자체.등급 등급.으로 으로.판단 판단.하 하.므로 므로.저 저.신용자 신용자.도 도.대출 대출.가능 가능.4 4.부채 부채.많 많.다면 다면.부채 부채.통합 통합.상품 상품.으로 으로.전환 전환.가능 가능.5 5.원리금 원리금.균 균.등 등.방식 방식.이자 이자.만 만.납입 납입.하 하.만기 만기.일시 일시.로 로.전환 전환.가능 가능.6 6.가상 가상.조회 조회.통해 통해.한도 한도.및 및.금리 금리.한 한.번 번.에 에.확인 확인.가능 가능.이런 이런.분 분.들 들.께 께.권해 권해.드립니다 드립니다.1 1.이미 이미.시중 시중.은행 은행.권 권.에서 에서.대출 대출.한도 한도.모두 모두.사용 사용.중 중.신 신.분 분.2 2.기 기.대출 대출.의 의.원리금 원리금.균 균.등 등.방식 방식.으로 으로.인해 인해.월 월.납입금 납입금.액 액.부담 부담.스러우 스러우.신 신.분 분.3 3.총 총.대 대.출금액 출금액.작 작.으나 으나.대출 대출.건수 건수.많 많.아서 아서.관리 관리.안 안.되 되.시 시.분 분.4 4.이제 이제.라도 라도.대출 대출.로 로.인한 인한.신용 신용.등급 등급.관리 관리.및 및.상승 상승.에 에.관심 관심.있 있.으신 으신.분 분.신용 신용.에 에.대한 대한.기본 기본.적 적.인 인.상식 상식.과 과.지식 지식.알 알.아야 아야.하 하.시대 시대.입니다 입니다.최소한 최소한.의 의.지식 지식.본인 본인.알 알.아야 아야.금전 금전.적 적.손해 손해.보 보.일 일.없 없.습니다 습니다.신청 신청.방법 방법.상담 상담.또는 또는.00 00.시 시.00 00.분 분.상담 상담.라고 라고.답장 답장.보내 보내.주 주.시 시.거나 거나.전화 전화.주 주.시 시.면 면.친절 친절.하 하.고 고.안전 안전.한 한.상담 상담.으로 으로.도움 도움.드리 드리.겠 겠.습니다 습니다.수신 수신.희망 희망.하 하.지 지.않 않.으실 으실.경우 경우.에 에.거부 거부.라는 라는.답장 답장.주 주.시 시.면 면.수신 수신.거부 거부.목록 목록.에 에.등록 등록.시켜 시켜.두 두.번 번.다시 다시.발송 발송.되 되.지 지.않 않.도록 도록.조치 조치.취해 취해.드리 드리.겠 겠.습니다 습니다.무료 무료.거부 거부.제목 제목.없 없.음',
#  '광고.수탁 수탁.법인 법인.입니다 입니다.하루하루 하루하루.힘든 힘든.업무 업무.와 와.스트레스 스트레스.에 에.고생 고생.많 많.으십니다 으십니다.요즘 요즘.은행 은행.영업 영업.사칭 사칭.해 해.상담 상담.으로 으로.높 높.이율 이율.로 로.진행 진행.후 후.3 3.개월 개월.뒤 뒤.낮 낮.이율 이율.로 로.전환 전환.등 등.의 의.사기 사기.유형 유형.으로 으로.대부 대부.중개 중개.이용 이용.하 하.신 신.분 분.언제 언제.든 든.상담 상담.받 받.아 아.보 보.기 기.시 시.바랍니다 바랍니다.저희 저희.은행 은행.연합회 연합회.에 에.소속 소속.되 되.어 어.있 있.전문 전문.영업 영업.사원 사원.으로서 으로서.저희 저희.은행 은행.쪽 쪽.으로 으로.진행 진행.안 안.하 하.시 시.더라도 더라도.가장 가장.안 안.전한 전한.조회 조회.통해서 통해서.가장 가장.낮 낮.이율 이율.로 로.컨설팅 컨설팅.해 해.드릴 드릴.것 것.약속 약속.드립니다 드립니다.바쁘 바쁘.신 신.와중 와중.에 에.도 도.저희 저희.와 와.상담 상담.하 하.셔서 셔서.이상 이상.적 적.인 인.채 채.무 무.설계 설계.상담 상담.받 받.아 아.보 보.세요 세요.통합 통합.전환 전환.상품 상품.1 1.채무 채무.과다 과다.로 로.인해 인해.추가 추가.자금 자금.필요 필요.혹은 혹은.채무 채무.통합 통합.원하 원하.시 시.분 분.2 2.2 2.금융 금융.권 권.이상 이상.사용 사용.비중 비중.높 높.거나 거나.돌려 돌려.막 막.기 기.하 하.고 고.계신 계신.분 분.3 3.원리금 원리금.균 균.등 등.방식 방식.이자 이자.만기 만기.일시 일시.만 만.내 내.방식 방식.으로 으로.변경 변경.4 4.카드 카드.론 론.현금 현금.서비스 서비스.사용 사용.잦 잦.분 분.들 들.카드 카드.론 론.과 과.현금 현금.서비스 서비스.신용 신용.등급 등급.에 에.가장 가장.악영향 악영향.미칩니다 미칩니다.5 5.사용 사용.중 중.인 인.금액 금액.작 작.으나 으나.건수 건수.여러 여러.건 건.으로 으로.이용 이용.중 중.인 인.분 분.들 들.신용 신용.등급 등급.하락 하락.의 의.입니다 입니다.6 6.월 월.납입금 납입금.액 액.최소 최소.절반 절반.이상 이상.으로 으로.줄이 줄이.고 고.싶 싶.으신 으신.분 분.들 들.7 7.3 3.개월 개월.뒤 뒤.에 에.전환 전환.해 해.주 주.겠 겠.다는 다는.조건 조건.으로 으로.대부 대부.혹은 혹은.조증 조증.상품 상품.사용 사용.토록 토록.유도 유도.한 한.사기 사기.유형 유형.의 의.피해 피해.로 로.답답 답답.해 해.하 하.시 시.분 분.직장 직장.인 인.사업자 사업자.님 님.신용 신용.상품 상품.1 1.1 1.억 억.3000 3000.만 만.원 원.까지 까지.2 2.3 3.67 67.%( %(.등급 등급.차등 차등.적용 적용.3 3.연봉 연봉.의 의.300 300.% %.내 내.한도 한도.4 4.담보 담보.상품 상품.아파트 아파트.물건 물건.만 만.적용 적용.5 5.차량 차량.오토 오토.론 론.무직 무직.가능 가능.개인 개인.사업자 사업자.or or.프리랜서 프리랜서.직장 직장.인 인.햇 햇.살 살.론 론.혹은 혹은.새 새.희망 희망.홀씨 홀씨.상품 상품.안내 안내.1 1.연봉 연봉.4000 4000.만 만.미만 미만.2 2.재직 재직.사업 사업.개시 개시.혹은 혹은.입사 입사.3 3.개월 개월.이상 이상.새 새.희망 희망.상품 상품.6 6.개월 개월.3 3.신용 신용.등급 등급.8 8.등급 등급.도 도.가능 가능.어떠 어떠.한 한.경우 경우.의 의.상담 상담.라도 라도.서류 서류.먼저 먼저.요구 요구.하 하.진 진.않 않.습니다 습니다.사금융 사금융.대부 대부.중개 중개.과다 과다.조회 조회.와 와.신용 신용.하락 하락.의 의.시작 시작.입니다 입니다.신청 신청.방법 방법.010 010.6736 6736.9115 9115.전화 전화.주 주.시 시.거나 거나.문자 문자.로 로.상담 상담.또는 또는.00 00.시 시.00 00.분 분.상담 상담.라고 라고.전송 전송.해 해.주 주.시 시.거나 거나.카카오톡 카카오톡.아이디 아이디.momo momo.5778 5778.로 로.친구 친구.추가 추가.상담 상담.신청 신청.혹은 혹은.전화 전화.주 주.시',
#  '광고.KoreaXXX KoreaXXX.무료 무료.재무 재무.포토 포토.폴리오 폴리오.신청 신청.하 하.고 고.미래 미래.플랜 플랜.설계 설계.해 해.보 보.세요 세요.신용 신용.등급 등급.관리 관리.팀 팀.에서 에서.등급 등급.올릴 올릴.수 수.있 있.tip tip.알려 알려.드립니다 드립니다.1 1.주 주.거래 거래.은행 은행.만들 만들.기 기.은행 은행.자사 자사.거래 거래.실적 실적.많 많.고객 고객.에게 에게.좋 좋.평점 평점.합니다 합니다.2 2.일시불 일시불.사용 사용.지속 지속.적 적.인 인.할부 할부.누적 누적.부채 부채.증가 증가.로 로.인식 인식.등급 등급.에 에.부정 부정.적 적.요인 요인.3 3.적정 적정.카드 카드.사용 사용.한도 한도.에 에.가깝 가깝.게 게.쓰 쓰.지 지.말 말.고 고.2030 2030.% %.수준 수준.유지 유지.4 4.공과금 공과금.성실 성실.납부 납부.하 하.기 기.각종 각종.공과금 공과금.6 6.개월 개월.이상 이상.성실히 성실히.납부 납부.하 하.면 면.가산점 가산점.받 받.아요 아요.5 5.이자 이자.높 높.대출 대출.부터 부터.갚 갚.자 자.대출금 대출금.상환 상환.만 만.잘 잘.해도 해도.등급 등급.향상 향상.에 에.도움 도움.됩니다 됩니다.6 6.신용 신용.등급 등급.꾸준히 꾸준히.관리 관리.등급 등급.하락 하락.요인 요인.인 인.연체 연체.하 하.지 지.않 않.기 기.위해 위해.평소 평소.꾸준히 꾸준히.관리 관리.및 및.확인 확인.직장 직장.인 인.안내 안내.금리 금리.연 연.2 2.82 82.%( %(.CD CD.금리 금리.변동 변동.직장 직장.인 인.기준 기준.공무원 공무원.외감 외감.업체 업체.대 대.기업 기업.우대 우대.한도 한도.1 1.억 억.4 4.천만 천만.원 원.까지 까지.일반 일반.업체 업체.개인사 개인사.업장 업장.근로자 근로자.도 도.진행 진행.가능 가능.신용 신용.도와 도와.상관없이 상관없이.자체 자체.등급 등급.으로 으로.판단 판단.신청 신청.방법 방법.문자 문자.로 로.상담 상담.라고 라고.답장 답장.주 주.시 시.거나 거나.전화 전화.주 주.시 시.면 면.정직 정직.하 하.고 고.친절히 친절히.상담 상담.으로 으로.도움 도움.드릴께요 드릴께요.신용 신용.상담 상담.위한 위한.신용 신용.조회 조회.등급 등급.에 에.영향 영향.미치 미치.지 지.않 않.습니다 습니다.카카오톡 카카오톡.신청 신청.방법 방법.ID ID.citi citi.58 58.아이디 아이디.검색 검색.후 후.친구 친구.추가 추가.후 후.상담 상담.라는 라는.카톡 카톡.남겨 남겨.주 주.세요 세요.빠르 빠르.게 게.답변 답변.드리 드리.겠 겠.습니다 습니다.부채 부채.통합 통합.상품 상품.안내 안내.자격 자격.조건 조건.사 사.대 대.보험 보험.가능 가능.한 한.직장 직장.인 인.and and.재직 재직.1 1.년 년.이상 이상.1 1.년 년.미만 미만.도 도.직군 직군.과 과.등급 등급.에 에.따라 따라.가능 가능.할 할.수 수.있 있.습니다 습니다.한도 한도.연봉 연봉.대비 대비.300 300.% %.까지 까지.금리 금리.최저 최저.3 3.%( %(.등급 등급.차등 차등.적용 적용.부 부.채 채.통 통.합 합.요약 요약.월 월.납입금 납입금.대폭 대폭.절감 절감.신용 신용.도 도.대폭 대폭.상승 상승.모든 모든.채무 채무.1 1.금융 금융.으로 으로.그 그.뤠잇 뤠잇.하 하.게 게.원리금 원리금.균 균.등 등.방식 방식.이자 이자.만 만.내 내.방식 방식.으로 으로.전환 전환.재직 재직.기간 기간.1 1.년 년.분 분.들 들.만 만.가능 가능.합니다 합니다.최근 최근.6 6.개월 개월.간 간.연체 연체.사실 사실.있 있.다면 다면.진행 진행.안 안.됩니다 됩니다.신청 신청.방법 방법.문자 문자.로 로.상담 상담.라고 라고.답장 답장.주 주.시 시.거나 거나.전화 전화.주 주.시 시.면 면.정직 정직.하 하.고 고.친절히 친절히.상담 상담.으로 으로.도움 도움.드릴께요 드릴께요.드림 드림.햇 햇.살 살.론 론.상품 상품.1 1.최저 최저.3000 3000.만 만.원 원.까지 까지.2 2.최대 최대.10 10.% %.내외 내외.3 3.20 20.% %.이상 이상.의',
#  '광고.상품 상품.안내 안내.안녕 안녕.하 하.세요 세요.저희 저희.에서 에서.신규 신규.상품 상품.출시 출시.되 되.며 며.채무 채무.통합 통합.대환 대환.상품 상품.신규 신규.상품 상품.안내 안내.차 차.연락 연락.드립니다 드립니다.여유 여유.시간 시간.내 내.어 어.읽 읽.어 어.주 주.신다면 신다면.도움 도움.되 되.실 실.거 거.라 라.생각 생각.되 되.어 어.안내장 안내장.보내 보내.드립니다 드립니다.금리 금리.최 최.저 저.3 3.75 75.% %.부 부.터 터.기준 기준.금리 금리.산 산.금리 금리.한 한.도최 도최.대 대.1 1.억 억.원 원.까지 까지.대환 대환.자금 자금.추가 추가.자금 자금.조건 조건.만 만.23 23.세 세.이상 이상.직장 직장.인 인.개인 개인.사업자 사업자.1 1.가상 가상.조회 조회.로 로.한도 한도.금리 금리.한 한.번 번.에 에.알 알.수 수.있 있.습니다 습니다.2 2.행사 행사.금융 금융.등 등.1 1.금융 금융.권 권.으로 으로.대환 대환.할 할.수 수.있 있.습니다 습니다.3 3.시 시.중 중.은행 은행.보다 보다.높 높.한도 한도.자부 자부.합니다 합니다.4 4.꼭 꼭.주 주.거래 거래.은행 은행.아니 아니.라도 라도.상관없이 상관없이.진행 진행.가능 가능.합니다 합니다.담 담.보 보.원리금 원리금.상환 상환.원금 원금.과 과.이자 이자.함께 함께.상환 상환.으로 으로.사용 사용.중 중.인 인.상품 상품.만기 만기.일시 일시.이자 이자.만 만.납부 납부.상품 상품.으로 으로.전환 전환.가능 가능.최 최.저 저.금리 금리.최 최.대 대.한도 한도.장기 장기.모기지 모기지.일반 일반.담보 담보.상담 상담.가능 가능.채무 채무.통합 통합.상품 상품.원리금 원리금.균등 균등.원금 원금.자 자.방식 방식.이자 이자.만 만.내 내.방식 방식.으로 으로.전환 전환.신용 신용.등급 등급.7 7.등급 등급.내 내.의 의.직장인 직장인.면 면.부채 부채.과다 과다.로 로.인해 인해.추가 추가.진행 진행.어렵 어렵.다면 다면.통합 통합.해 해.드리 드리.겠 겠.습니다 습니다.연소 연소.득 득.대비 대비.최 최.대 대.300 300.% %.이내 이내.가능 가능.최근 최근.6 6.개 개.월간 월간.연체 연체.사실 사실.있 있.다면 다면.진행 진행.불가 불가.카드 카드.론 론.현금 현금.서비스 서비스.사용 사용.잦 잦.분 분.들 들.채무 채무.금액 금액.작 작.으나 으나.건수 건수.여러 여러.건 건.으로 으로.이용 이용.중 중.인 인.분 분.들 들.채 채.무통 무통.합의 합의.핵심 핵심.포인트 포인트.1 1.월 월.납입 납입.액 액.45 45.% %.85 85.% %.감소 감소.및 및.자금액 자금액.최 최.대 대.85 85.% %.감소 감소.시켜 시켜.드립니다 드립니다.2 2.신용도 신용도.최 최.대 대.등급 등급.1 1.등급 등급.까지 까지.상승 상승.시켜 시켜.드립니다 드립니다.3 3.퍼져 퍼져.있 있.부채 부채.13 13.건 건.으로 으로.줄여 줄여.관리 관리.하 하.기 기.편하 편하.게 게.만들 만들.어 어.드립니다 드립니다.4 4.추가 추가.자금 자금.필요 필요.할 할.때 때.은행 은행.권 권.으로 으로.가능 가능.하 하.실 실.수 수.있 있.게 게.해 해.드립니다 드립니다.정부 정부.지원 지원.사 사.잇돌 잇돌.햇살 햇살.론 론.드림 드림.1 1.한도 한도.3000 3000.만 만.원 원.까지 까지.대환 대환.자금 자금.포함 포함.2 2.금리 금리.8 8.% %.15 15.% %.까지 까지.3 3.자격 자격.조건 조건.20 20.% %.이상 이상.의 의.대출 대출.6 6.개 개.월 월.이상 이상.사용 사용.중 중.인 인.분 분.홍보 홍보.성 성.문자 문자.이나 이나.필요 필요.한 한.한 한.분 분.한 한.분 분.에게 에게.도움 도움.되 되.고자 고자.합니다 합니다.신청 신청.방법 방법.전화 전화.주 주.시 시.거나 거나.부재중 부재중.일시 일시.광고 광고.국민',
#  '광고.안 안.요페 요페.퍼 퍼.에서 에서.고객 고객.님 님.분 분.들 들.개인 개인.신용 신용.상담 상담.및 및.접수 접수.업무 업무.맡 맡.고 고.있 있.신용 신용.대출 대출.팀장 팀장.입니다 입니다.항상 항상.건강 건강.하 하.시 시.고 고.행복 행복.한 한.일 일.들 들.가득 가득.하 하.시 시.길 길.기원 기원.드립니다 드립니다.행여 행여.바쁜 바쁜.업무 업무.에 에.지장 지장.드릴까 드릴까.봐 봐.메세지 메세지.로 로.연락 연락.드립니다 드립니다.메세지 메세지.보내 보내.드리 드리.이유 이유.다름 다름.아니 아니.라 라.법정 법정.최고 최고.금리 금리.인하 인하.로 로.2 2.월 월.부터 부터.대환 대환.상품 상품.및 및.서민 서민.금융 금융.상품 상품.금리 금리.기준 기준.많이 많이.완화 완화.되 되.었 었.으나 으나.판매 판매.한도 한도.매우 매우.부족 부족.합니다 합니다.현재 현재.2 2.금융 금융.권 권.신용 신용.보유 보유.중 중.시 시.거나 거나.자금 자금.필요 필요.하 하.신데 신데.주 주.거래 거래.은행 은행.에서 에서.더 더.이상 이상.한도 한도.발생 발생.하 하.지 지.않 않.으시 으시.다면 다면.아래 아래.내용 내용.꼭 꼭.읽 읽.어 어.봐 봐.주 주.시 시.고 고.서둘러 서둘러.상담 상담.받 받.아 아.보 보.시 시.길 길.권유 권유.드립니다 드립니다.2 2.금융 금융.권 권.에서 에서.고금리 고금리.신용 신용.보유 보유.중 중.신 신.분 분.들 들.위해 위해.은행 은행.권 권.전환 전환.과 과.추가 추가.한도 한도.위하 위하.여 여.페퍼 페퍼.직장 직장.인 인.신용 신용.상품 상품.출시 출시.하 하.였 였.습니다 습니다.최근 최근.조건 조건.상당수 상당수.많 많.부분 부분.완화 완화.되 되.어 어.안내 안내.해 해.드립니다 드립니다.직장 직장.인 인.신용 신용.상품 상품.1 1.급여 급여.소득 소득.자 자.전문직 전문직.대상 대상.급여 급여.대상자 대상자.모두 모두.2 2.최저 최저.6 6.9 9.% %.부터 부터.연체 연체.기록 기록.과다 과다.하 하.지 지.않 않.다면 다면.가능 가능.3 3.최대 최대.1 1.억 억.4 4.천 천.급여 급여.의 의.최대 최대.21 21.배 배.까지 까지.가능 가능.4 4.연봉 연봉.대비 대비.부채 부채.채무 채무.율 율.높 높.으셔도 으셔도.가능 가능.합니다 합니다.원리금 원리금.상환 상환.방식 방식.이자 이자.만 만.내 내.만기 만기.일시 일시.상품 상품.으로 으로.전환 전환.가능 가능.매달 매달.내 내.원리금 원리금.부담 부담.되 되.시 시.거나 거나.고금리 고금리.이용 이용.중 중.라면 라면.자신 자신.있 있.게 게.권해 권해.드립니다 드립니다.현재 현재.은행 은행.권 권.에서 에서.가장 가장.완화 완화.된 된.조건 조건.의 의.신용 신용.대출 대출.입니다 입니다.5 5.신청 신청.방법 방법.언제나 언제나.전화 전화.주 주.시 시.면 면.친절 친절.하 하.게 게.상담 상담.해 해.드리 드리.겠 겠.습니다 습니다.가능 가능.조회 조회.신용 신용.등급 등급.에 에.전혀 전혀.영향 영향.주 주.지 지.않 않.습니다 습니다.모바일 모바일.조회 조회.로 로.가능 가능.여부 여부.먼저 먼저.확인 확인.가능 가능.하 하.시 시.며 며.서류 서류.접수 접수.시 시.은행 은행.방문 방문.없이 없이.계신 계신.지역 지역.으로 으로.직접 직접.찾아뵙 찾아뵙.고 고.신분 신분.확인 확인.해 해.드리 드리.고 고.접수 접수.진행 진행.도와 도와.드립니다 드립니다.항상 항상.정직 정직.고객 고객.님 님.의 의.힘 힘.되 되.페퍼 페퍼.되 되.도록 도록.노력 노력.하 하.겠 겠.습니다 습니다.위 위.문자 문자.당 당.행과 행과.상담 상담.하 하.셨 셨.고 고.상품 상품.서비스 서비스.안내 안내.등 등.에 에.동의 동의.하 하.셨 셨.던 던.분 분.들 들.대상 대상.으로 으로.한하 한하.여 여.보내 보내.고 고.있 있.습니다 습니다.혹시 혹시.당 당.행 행.거래 거래.와 와.관련 관련.전혀 전혀.없 없.으실 으실.경우 경우.번호 번호.오 오.기 기.로 로.인한 인한.오류 오류.있 있.수 수.있 있.으며 으며.잘못 잘못.된 된.수신 수신.받 받.으셨 으셨.거나 거나.수신 수신.원하 원하.지 지.않 않.으실 으실.경우 경우.거부 거부.문자 문자.남 남.광고 광고.안',
#  '광고.안녕 안녕.하 하.세요 세요.여신 여신.영업부 영업부.입니다 입니다.각종 각종.홍보 홍보.전화 전화.와 와.문자 문자.받 받.으셨을 으셨을.텐데 텐데.우선 우선.장문 장문.의 의.문자 문자.드려 드려.정말 정말.죄송 죄송.합니다 합니다.그럼에도 그럼에도.문자 문자.보내 보내.드리 드리.것 것.한국자산관리공사 한국자산관리공사.정부 정부.기관 기관.자금 자금.지원 지원.으로 으로.실행 실행.되 되.국민 국민.행복 행복.마이너스 마이너스.통장 통장.으로 으로.대출 대출.안내 안내.차 차.연락 연락.드렸 드렸.습니다 습니다.상품 상품.개요 개요.마이너스 마이너스.통장 통장.형태 형태.의 의.저 저.신용 신용.자 자.및 및.고금리 고금리.사용 사용.자 자.대출 대출.전환 전환.지원 지원.상품 상품.대 대.출한 출한.도 도.500 500.만 만.원 원.8000 8000.만 만.원 원.까지 까지.개인 개인.별 별.신용 신용.및 및.직급 직급.에 에.따라 따라.차이 차이.있 있.음 음.이율 이율.최저 최저.2 2.5 5.% %.최고 최고.8 8.5 5.% %.자격 자격.조건 조건.사업자 사업자.사업자 사업자.등록증 등록증.소지자 소지자.로써 로써.정상 정상.적 적.인 인.사업 사업.활동 활동.자 자.급여 급여.소득 소득.자 자.3 3.개월 개월.이상 이상.급여 급여.소득 소득.확인 확인.자 자.주부 주부.고금리 고금리.사용 사용.자 자.및 및.신규 신규.대출 대출.신청자 신청자.무직자 무직자.고금리 고금리.사용 사용.자 자.및 및.신규 신규.대출 대출.신청자 신청자.담당자 담당자.와 와.별도 별도.의 의.상담 상담.진행 진행.절차 절차.담당자 담당자.배정 배정.및 및.접수 접수.대출 대출.한도 한도.이율 이율.산정 산정.및 및.승인 승인.신청자 신청자.거래 거래.지점 지점.파악 파악.및 및.진행 진행.지점 지점.배정 배정.신청자 신청자.배정 배정.지점 지점.으로 으로.승인서 승인서.발송 발송.신청자 신청자.서류 서류.지참 지참.후 후.지점 지점.방문 방문.접수 접수.및 및.최종 최종.대출금 대출금.수령 수령.담당자 담당자.상담 상담.및 및.심사 심사.만 만.도움 도움.드리 드리.며 며.최종 최종.고객 고객.님 님.께서 께서.직접 직접.가까운 가까운.지점 지점.방문 방문.하 하.셔야 셔야.대출금 대출금.대출 대출.카드 카드.수령 수령.가능 가능.하 하.십니다 십니다.상담 상담.가능 가능.시간 시간.오전 오전.9 9.00 00.오후 오후.18 18.00 00.담당자 담당자.전국 전국.은행 은행.연합회 연합회.등 등.04 04.06 06.002 002.대리',
#  '광고.항상 항상.하나 하나.은행 은행.이용 이용.해 해.주 주.셔서 셔서.감사 감사.합니다 합니다.2018 2018.년 년.08 08.월 월.신상품 신상품.출시 출시.되 되.여서 여서.안 안.내 내.드립니다 드립니다.낮 낮.금리 금리.로 로.정부 정부.지원 지원.상품 상품.이용 이용.할 할.수 수.있 있.습니다 습니다.고민 고민.하 하.지 지.마시 마시.고 고.전화 전화.주세요 주세요.내용 내용.신상품 신상품.출시 출시.안 안.내본 내본.상품 상품.서민 서민.지원 지원.대출 대출.로 로.정부 정부.에서 에서.지원 지원.하 하.고 고.하나 하나.에 에.만 만.이용 이용.할 할.수 수.있 있.상품 상품.입니다 입니다.상품 상품.특징 특징.1 1.무담보 무담보.무 무.수수료 수수료.2 2.신용 신용.등급 등급.상관없이 상관없이.3 3.최고 최고.한도 한도.3 3.억 억.4 4.최하 최하.금리 금리.3 3.% %.5 5.상환 상환.수수료 수수료.없이 없이.자유 자유.롭 롭.게 게.상환 상환.가능 가능.6 6.기존 기존.채무자 채무자.저금리 저금리.전환 전환.가능 가능.자격 자격.조건 조건.1 1.만 만.21 21.세 세.이상 이상.2 2.직장 직장.인 인.사업자 사업자.프리랜서 프리랜서.주부 주부.학생 학생.3 3.최근 최근.부결 부결.자 자.다중 다중.채무자 채무자.가능 가능.신청 신청.기간 기간.09 09.월 월.24 24.일 일.마감 마감.접수 접수.자 자.많 많.으니 으니.빠른 빠른.신청 신청.바랍니다 바랍니다.신청 신청.방법 방법.본 본.문자 문자.수신 수신.번호 번호.로 로.전화 전화.하 하.셔서 셔서.1 1.번 번.누르 누르.시 시.고 고.금액 금액.입력 입력.하 하.시 시.면 면.접수 접수.완료 완료.신청자 신청자.많 많.아 아.상담 상담.지연 지연.될 될.수 수.있 있.습니다 습니다.양해 양해.부탁 부탁.드립니다 드립니다.신청 신청.접수 접수.상담 상담.무료 무료.수신 수신.거부 거부.최',
#  '광고.새해맞이 새해맞이.행복 행복.가득 가득.페스티벌 페스티벌.새해 새해.이벤트 이벤트.로 로.저희 저희.에서 에서.파격 파격.적 적.인 인.지원 지원.상품 상품.출시 출시.되 되.었 었.습니다 습니다.주 주.거래 거래.고객 고객.아니 아니.어도 어도.누구 누구.나 나.쉽 쉽.고 고.빠르 빠르.게 게.이용 이용.가능 가능.한 한.은행 은행.상품 상품.낮 낮.금리 금리.로 로.대출금 대출금.이용 이용.하 하.실 실.수 수.있 있.마지 마지.입니다 입니다.고민 고민.하 하.지 지.마시 마시.고 고.전화 전화.주세요 주세요.자격 자격.조건 조건.1 1.만 만.20 20.세 세.65 65.세 세.까지 까지.2 2.직장 직장.인 인.사업자 사업자.일용직 일용직.주부 주부.학생 학생.3 3.최근 최근.부결 부결.자 자.다중 다중.채무자 채무자.가능 가능.상품 상품.조건 조건.1 1.개인 개인.등급 등급.무관 무관.2 2.기존 기존.이용 이용.금액 금액.많 많.아도 아도.가능 가능.3 3.최저 최저.조건 조건.3 3.0 0.% %.부터 부터.채무 채무.통합 통합.1 1.현금 현금.서비스 서비스.신용 신용.카드 카드.사용 사용.많 많.으신 으신.분 분.2 2.다중 다중.채무 채무.하나 하나.로 로.통합 통합.하 하.실 실.분 분.3 3.월 월.납입금 납입금.50 50.% %.이상 이상.절감 절감.효과 효과.있 있.습니다 습니다.요약 요약.37 37.% %.의 의.저금리 저금리.최대 최대.9 9.천 천.까지 까지.중도 중도.상환 상환.수수료 수수료.없 없.음 음.고금리 고금리.대출 대출.낮 낮.금리 금리.로 로.대환 대환.및 및.통합 통합.월 월.납입 납입.액 액.50 50.% %.이상 이상.감소 감소.주 주.거래 거래.은행 은행.여부 여부.관계없이 관계없이.진행 진행.가능 가능.카드 카드.론 론.현금 현금.서비스 서비스.대부 대부.업체 업체.이용자 이용자.진행 진행.가능 가능.신청 신청.기간 기간.1 1.월 월.30 30.일 일.까지 까지.접수 접수.분 분.우선 우선.우선 우선.혜택 혜택.1 1.현재 현재.신청자 신청자.많 많.습니다 습니다.2 2.금일 금일.신청 신청.시 시.우선 우선.진행 진행.가능 가능.3 3.최근 최근.승인 승인.지급금 지급금.대폭 대폭.상승 상승.4 4.한 한.도소 도소.진시 진시.까지 까지.전폭 전폭.적 적.진행 진행.합니다 합니다.채무 채무.통합 통합.추가 추가.자금 자금.필요 필요.하 하.신 신.분 분.모두 모두.서둘러 서둘러.신청 신청.하 하.세요 세요.오전 오전.9 9.시 시.오후 오후.6 6.시 시.까지 까지.접수 접수.서민 서민.들 들.의 의.희망 희망.키우 키우.금융 금융.대한민국 대한민국.의 의.더 더.든든 든든.한 한.내일 내일.만들 만들.어 어.갑니다 갑니다.마지막 마지막.으로 으로.죄송 죄송.하 하.지만 지만.번호 번호.표기 표기.로 로.인한 인한.오류 오류.있 있.수 수.있 있.으며 으며.잘못 잘못.된 된.수신 수신.받 받.으셨 으셨.거나 거나.수신 수신.원하 원하.지 지.않 않.으실 으실.경우 경우.거부 거부.문자 문자.남겨 남겨.주 주.시 시.면 면.조치 조치.해 해.드리 드리.도록 도록.하 하.겠 겠.습니다 습니다.고객 고객.관리 관리.부 부.심의 심의.필 필.2017 2017.02 02.013 013.유효 유효.기간 기간.2017 2017.10 10.152018 152018.9 9.14 14.까지 까지.무료 무료.거부 거부.광고']

# %%
X_test = []
for lwords in test_doc:
    
    temp = []
    for x, y in get_couple(lwords[0]):
        temp.append("{}.{}".format(x, y))
    
    X_test.append(" ".join(temp))

# %%
# tf-idf 써보기

from sklearn.feature_extraction.text import TfidfVectorizer

tfv = TfidfVectorizer()

tfv.fit(X_train)

# tfv.fit_transform(X_train)
vec_x_train = tfv.transform(X_train).toarray()
vec_x_test = tfv.transform(X_test).toarray()

# %%
# 해싱벡터라이즈 써보기
from sklearn.feature_extraction.text import HashingVectorizer

hv = HashingVectorizer(n_features=300000)
hv.fit(X_train)

vec_x_train = hv.transform(X_train).toarray()
vec_x_test = hv.transform(X_test).toarray()

# %%
len(tfv.vocabulary_)
# Out:
# 15693

# %%
from sklearn.feature_extraction.text import CountVectorizer
v=CountVectorizer()

v.fit(X_train)

vec_x_train= v.transform(X_train).toarray()
vec_x_test= v.transform(X_test).toarray()

# %%
v.transform(X_train)
# Out:
# <19533x15693 sparse matrix of type '<class 'numpy.int64'>'
# 	with 635136 stored elements in Compressed Sparse Row format>

# %%
# Out:
# 306531369

# %%
from sklearn.naive_bayes import MultinomialNB  # model 관련
from sklearn.metrics import roc_auc_score  

m1= MultinomialNB()
m1.fit(vec_x_train,Y_train)

y_train_pred1=m1.predict_proba(vec_x_train)
y_train_pred1_one= [ i[1]  for i in y_train_pred1]

y_test_pred1=m1.predict_proba(vec_x_test)
y_test_pred1_one= [ i[1]  for i in y_test_pred1]

# %%
ls
# Out:
# '11회 data'/           Mecab-ko-for-Google-Colab/   train.csv
#  beginner_code.ipynb   public_test.csv              Untitled0.ipynb
# 'dacon data.ipynb'     submission_제출양식.csv

# %%
test
# Out:
#           id  ... smishing
# 0     340000  ...        2
# 1     340001  ...        2
# 2     340002  ...        2
# 3     340003  ...        2
# 4     340004  ...        2
# ...      ...  ...      ...
# 1621  341621  ...        2
# 1622  341622  ...        2
# 1623  341623  ...        2
# 1624  341624  ...        2
# 1625  341625  ...        2
#
# [1626 rows x 4 columns]

# %%
sub = pd.read_csv('submission_제출양식.csv')

# %%
sub['smishing'] = y_test_pred1_one

sub.to_csv('tfidf_multiNB.csv',index=False)

# %%
sub
# Out:
#           id      smishing
# 0     340000  8.978513e-04
# 1     340001  1.806545e-02
# 2     340002  3.971244e-05
# 3     340003  5.130586e-05
# 4     340004  1.409122e-04
# ...      ...           ...
# 1621  341621  1.616251e-07
# 1622  341622  1.362140e-06
# 1623  341623  1.402413e-05
# 1624  341624  4.190341e-04
# 1625  341625  2.396164e-02
#
# [1626 rows x 2 columns]
